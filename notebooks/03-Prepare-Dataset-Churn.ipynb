# %%
from Utils.DataLoader import DataLoader
from Utils.DuckDb import DuckDb
from datetime import datetime
import pandas as pd
from typing import List
import math
import numpy as np

# %%
DUCK_DB_UTILS = DuckDb()

# %%
MININUM_USERS_TO_CONSIDER = 1_500_000
BATCH_SIZE_TO_GET_DATA_FROM_DATABASE = 50_000
PROCESS_USERS_BATCH_SIZE = 10_000

# MININUM_USERS_TO_CONSIDER = 10_000
# BATCH_SIZE_TO_GET_DATA_FROM_DATABASE = 10_000
# PROCESS_USERS_BATCH_SIZE = 10_000

# %%
# Max safra = 201702, so we need to consider three months before
MAX_SAFRA_TO_CONSIDER = 201611

# %%
datetime_string_identifier = datetime.now().strftime('%Y_%m_%d_%Hh%Mm')
DATABASE_NEW_TABLE = 'treated_churn_dataset_' + datetime_string_identifier
TEMP_TABLE_NAME = 'temp_' + datetime_string_identifier

# %%
DUCK_DB_CONN = DUCK_DB_UTILS.get_connection()

# %%
def get_user_list(limit: int = 9999999999, offset: int = 0) -> List[str]:
    conn = DUCK_DB_UTILS.get_connection()
    query = '''
        SELECT DISTINCT(msno)
        FROM main.user_logs ul
        ORDER BY msno
        LIMIT ?
        OFFSET ?
    '''
    query_results = conn.execute(query, [limit, offset]).fetchall()
    result = list(
        map(
            lambda qr: qr[0], query_results
        )
    )
    return result

# %%
def get_dataset_by_users(msnos: List[str]) -> pd.DataFrame:
    query = '''
        SELECT
            ----------------------
            -- Calculated fields --
            ----------------------
            50 + (0.0051 * num_unq) + (0.0001 * ul.total_secs) AS cost,
            --	t.actual_amount_paid - cost AS net_profit,
            ----------------------
            -- User Logs fields --
            ----------------------
            ul.msno,
            ul.safra,
            ul.num_25,
            ul.num_50,
            ul.num_75,
            ul.num_985,
            ul.num_100,
            ul.num_unq,
            ul.total_secs,
            ul.total_hours,
            -------------------------
            -- Transactions fields --
            -------------------------
            t.msno,
            t.payment_method_id,
            t.payment_plan_days,
            t.plan_list_price,
            t.actual_amount_paid,
            t.is_auto_renew,
            t.is_cancel,
            t.safra,
            t.transaction_date_year,
            t.transaction_date_month,
            t.transaction_date_day,
            t.transaction_date_day_of_week,
            t.transaction_date_day_of_year,
            t.membership_expire_date_year,
            t.membership_expire_date_month,
            t.membership_expire_date_day,
            t.membership_expire_date_day_of_week,
            t.membership_expire_date_day_of_year,
            t.discount,
            t.price_per_month,
            ---------------------
            -- Members columns --
            ---------------------
            m.msno as members_msno,
            m.safra as members_safra,
            m.city,
            m.registered_via,
            m.is_active,
            m.registration_init_time_year,
            m.registration_init_time_month,
            m.registration_init_time_day,
            m.registration_init_time_day_of_week,
            m.registration_init_time_day_of_year
        FROM
            main.user_logs ul
        INNER JOIN
            main.transactions t ON
            t.msno == ul.msno
            AND t.safra == ul.safra
        LEFT JOIN
            main.members m ON
            m.msno = ul.msno AND m.safra = ul.safra
        WHERE
            ul.msno IN ?
        ORDER BY
            ul.msno,
            ul.safra
    '''

    conn = DUCK_DB_UTILS.get_connection()
    query_results = conn.execute(query, (msnos,)).fetch_df()
    return query_results

# %%
def create_database_table(df: pd.DataFrame):
    DUCK_DB_CONN.register('df_view', df)
    DUCK_DB_CONN.execute(
        f"CREATE TABLE IF NOT EXISTS {DATABASE_NEW_TABLE} AS SELECT * FROM df_view WHERE FALSE"
    )

# %%
def upload_dataframe_to_duck_db(df: pd.DataFrame):
    print(f'{datetime.now()} Inserindo {len(df)} registros na tabela {DATABASE_NEW_TABLE}')

    DUCK_DB_CONN.register('df', df)
    DUCK_DB_CONN.execute(
        f"INSERT INTO {DATABASE_NEW_TABLE} SELECT * FROM df"
    )

    print(f'{datetime.now()} Inseridos com sucesso')

# %%
def truncate_table():
    DUCK_DB_CONN.execute(
        f"TRUNCATE {DATABASE_NEW_TABLE}"
    )

# %%
def get_dataset() -> pd.DataFrame:
    all_dfs: List[pd.DataFrame] = []

    count = 0
    while count < MININUM_USERS_TO_CONSIDER:
        print(f'Processando count: {count}')

        users_msno = get_user_list(limit=BATCH_SIZE_TO_GET_DATA_FROM_DATABASE, offset=count)
        count += BATCH_SIZE_TO_GET_DATA_FROM_DATABASE

        all_dfs.append(
            get_dataset_by_users(users_msno)
        )

    print(f'Qtd. de dataframes: {len(all_dfs)}')

    all_dfs = list(
        filter(
            lambda df: df.__len__() > 0, all_dfs
        )
    )

    print(f'Qtd. de dataframes pós remoção dos vazios: {len(all_dfs)}')

    result = pd.concat(all_dfs)
    return result

# %%
# full_dataframe = get_dataset()
full_dataframe = pd.read_csv('./full-dataframe-cached-complete.csv')

# %%
full_dataframe.to_csv(f'./full-dataframe-cached-{datetime_string_identifier}.csv', index=False)

# %%
users_msno = list(full_dataframe['msno'].unique())

# %%
def get_next_safras(safra: int, month_qty: int) -> int:
    str_safra = str(safra)
    year, month = int(str_safra[:4]), int(str_safra[4:])

    month -= 1

    month += month_qty

    year += month // 12
    month = month % 12

    month += 1

    formatted_month = f'0{month}' if month < 10 else (month)
    return int(f'{year}{formatted_month}')

# %%
def get_previous_months_cols_values(user_df: pd.DataFrame, row: pd.Series, cols: List[str]) -> pd.DataFrame:
    current_safra = row['safra']

    safras_to_consider = [
        # -5, # previous safras
        # -4,
        # -3,
        -2,
        -1,

        # +1, # next safra
    ]

    if not all_safras_exist(user_df, current_safra, safras_to_consider):
        # print(f'Linha sem safras {safras_to_consider}')
        return row
    
    for col in cols:
        for safra_modifier in safras_to_consider:
            safra = get_next_safras(current_safra, safra_modifier)
            safra_row = user_df[user_df['safra'] == safra].reset_index()
            title = f'{col}{safra_modifier if safra_modifier < 0 else f"+{safra_modifier}"}M'
            row[title] = safra_row[col][0]

    # print(f'Linha {row} ajustada')
    return row


def all_safras_exist(user_df: pd.DataFrame, current_safra: int, safras_to_consider: List[int]) -> bool:
    for safra_modifier in safras_to_consider:
        next_safra = get_next_safras(current_safra, safra_modifier)
        filtered = user_df[user_df['safra'] == next_safra]

        if len(filtered) == 0:
            return False
        
    return True

# %%
# Key: user msno, value: row to copy if the current values are missing
USER_ROW_TO_COPY_MEMBER_INFO = {}

# %%
def calc_churn(df: pd.DataFrame, users_msno: List[str]) -> pd.DataFrame:
    global USER_ROW_TO_COPY_MEMBER_INFO

    df_by_users = {}

    print(f'Separando DataFrames por usuários')
    for index, usr in enumerate(users_msno):
        if index % 1000 == 0:
            print(f'-> {index} / {len(users_msno)}')
            
        df_by_users[usr] = df[df['msno'] == usr]


    def __calc_row_churn(user_df: pd.DataFrame, row: pd.Series):
        months_to_consider_churn = 3

        is_churn = False
        no_churn_information = False
        for m in range(months_to_consider_churn, 0, -1):
            next_safra = get_next_safras(row['safra'], m)

            # print('#' * 100)
            # print(f'User: {row["msno"]}')
            # print(f'Current safra: {row["safra"]}')
            # print(f'Next safra: {next_safra}')

            # Can't obtain info from this safra so on
            if row["safra"] > MAX_SAFRA_TO_CONSIDER:
                print('current safra > MAX_SAFRA_TO_CONSIDER!')
                no_churn_information = True
                break

            # print(f'Recuperando informações da safra {next_safra}')

            # print(user_df['safra'])
            next_safra_row = user_df[user_df['safra'] == next_safra].reset_index()

            # No more payment info, consider churn
            if len(next_safra_row) == 0:
                print(f'Safra {next_safra} não encontrada, pulando')
                is_churn = True
                break

            # Canceled, is churn
            if next_safra_row['is_cancel'][0] == True:
                print(f'Safra {next_safra} encontrada com is_cancel, marcando como churn!')
                is_churn = True
                break

        row['is_churn'] = is_churn
        row['no_churn_information'] = no_churn_information
        return row
    

    def __calc_row_churn_v2(user_df: pd.DataFrame, row: pd.Series):
        '''
        Consider only the third month ahead
        '''
        months_to_consider_churn = 3

        is_churn = False
        no_churn_information = False

        # print('#' * 100)
        # print(f'User: {row["msno"]}')
        # print(f'Current safra: {row["safra"]}')

        next_safra = get_next_safras(row['safra'], months_to_consider_churn)
        # print(f'Next safra: {next_safra}')

        # Can't obtain info from this safra so on
        if row["safra"] > MAX_SAFRA_TO_CONSIDER:
            # print('current safra > MAX_SAFRA_TO_CONSIDER!')
            no_churn_information = True

        else:
            next_safra_row = user_df[user_df['safra'] == next_safra].reset_index()

            # No more payment info, consider churn
            if len(next_safra_row) == 0:
                # print(f'Safra {next_safra} não encontrada, pulando')
                is_churn = True

            # Canceled, is churn
            elif next_safra_row['is_cancel'][0] == True:
                # print(f'Safra {next_safra} encontrada com is_cancel, marcando como churn!')
                is_churn = True

        row['is_churn'] = is_churn
        row['no_churn_information'] = no_churn_information
        return row



    def __fill_out_members_data_if_needed(user_df: pd.DataFrame, row: pd.Series):
        # Sometimes, we don't have the member information from all safras,
        # so we'll copy the values from the closer month

        members_msno_col = 'members_msno'

        # Already filled out
        if not row[members_msno_col] == None:
            row['_filled_out_members_info'] = 'Infos já existentes'
            return row

        # No user info available in any safras
        safras_df = user_df[~user_df[members_msno_col].isna()]
        if len(safras_df) == 0:
            row['_filled_out_members_info'] = 'Sem infos'
            return row

        members_cols_to_consider = [
            'city', 'registered_via', 'is_active', 'registration_init_time_year',
            'registration_init_time_month', 'registration_init_time_day',
            'registration_init_time_day_of_week', 'registration_init_time_day_of_year',
            'members_msno'
        ]

        if row['msno'] not in USER_ROW_TO_COPY_MEMBER_INFO:
            current_safra = row['safra']

            min_safra = safras_df['safra'].min()
            max_safra = safras_df['safra'].max()

            safra_to_consider = min_safra if current_safra < max_safra else max_safra

            row_to_copy = safras_df[safras_df['safra'] == safra_to_consider]
            row_to_copy = row_to_copy.reset_index()
            USER_ROW_TO_COPY_MEMBER_INFO[row['msno']] = row_to_copy
        else:
            row_to_copy = USER_ROW_TO_COPY_MEMBER_INFO[row['msno']]

        row['_filled_out_members_info'] = 'Copiadas'
        for col in members_cols_to_consider:
            row[col] = row_to_copy[col][0]

        return row


    rows = []
    users_qty = len(df_by_users.values())
    count = 0
    for msno, user_df in df_by_users.items():
        # print(f'Processando usuário {msno}')

        count += 1
        if count % 500 == 0:
            print(f'{datetime.now()} Processando usuário {count}/{users_qty} ({msno})')

        for _, user_row in user_df.iterrows():
            user_row = __fill_out_members_data_if_needed(user_df, user_row)
            # user_row = __calc_row_churn(user_df, user_row)
            user_row = __calc_row_churn_v2(user_df, user_row)

            user_row = get_previous_months_cols_values(
                user_df,
                user_row,
                ['num_unq', 'total_secs', 'num_25', 'num_50', 'num_75', 'num_985', 'num_100']
            )

            rows.append(user_row)
            # print(user_row)

        # Resetting this cache
        USER_ROW_TO_COPY_MEMBER_INFO = {}

    result = pd.DataFrame(rows)
    return result

# %%
def process_dataframe(full_dataframe: pd.DataFrame, users_msno: List[str]):
    # Process in batches
    total_iter = math.floor(len(full_dataframe) / PROCESS_USERS_BATCH_SIZE)

    print(f'Total de iterações: {total_iter}')
    print(f'Tamanho do Dataframe completo: {len(full_dataframe)}')

    result = None
    for i in range(0, total_iter):
        start = PROCESS_USERS_BATCH_SIZE * i
        end = PROCESS_USERS_BATCH_SIZE * (i + 1)

        print(f'{datetime.now()} Processando usuários ({start} / {end})')

        batch_users = users_msno[start:end]

        print(f'{datetime.now()} Separando um DF apenas com os usuários em questão')
        users_df = full_dataframe[full_dataframe['msno'].isin(batch_users)]

        print(f'Tamanho do Dataframe dos usuários do batch: {len(users_df)}')

        treated_df = calc_churn(
            users_df,
            batch_users
        )

        print(f'Tamanho da Dataframe: {len(treated_df)}')
        if len(treated_df) == 0:
            continue

        print('Removendo linhas sem informações de membros suficientes')
        treated_df = treated_df[~treated_df['members_msno'].isna()]

        # print('Removendo linhas sem informações suficientes para calcular o churn')
        # treated_df = treated_df[treated_df['no_churn_information'] == False]

        print(f'Tamanho da Dataframe pós filtros: {len(treated_df)}')

        create_database_table(treated_df)
        if i == 0:
            print('Truncando tabela')
            truncate_table()

        upload_dataframe_to_duck_db(treated_df)

        print('#' * 50)

        result = treated_df

    # Return the last processed one for debug purposes
    return result

# %%
treated_df = process_dataframe(
    full_dataframe,
    users_msno
)
# Out:
# Total de iterações: 450
# Tamanho do Dataframe completo: 4505078
# 2025-03-16 12:05:26.409700 Processando usuários (0 / 10000)
# 2025-03-16 12:05:26.409771 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 88711
# Separando DataFrames por usuários
# -> 0 / 10000
# -> 1000 / 10000
# -> 2000 / 10000
# -> 3000 / 10000
# -> 4000 / 10000
# -> 5000 / 10000
# -> 6000 / 10000
# -> 7000 / 10000
# -> 8000 / 10000
# -> 9000 / 10000
# 2025-03-16 12:06:23.423551 Processando usuário 500/10000 (+/E2nO8eLJPkPPpGxPku1WC7CzgEMkoe1qaToS/tIkE=)
# 2025-03-16 12:06:50.430619 Processando usuário 1000/10000 (+0MZZ5TW5El2B1kb+5hyH+OG+Fl9W3Nim/AoXqrSWqI=)
# 2025-03-16 12:07:16.699206 Processando usuário 1500/10000 (+1VHsZGC0OKuc2X8mUNpUmHgtE1XIxBckQyGiGwyx3s=)
# 2025-03-16 12:07:43.969137 Processando usuário 2000/10000 (+2Xud/e/yNe16BlzzyWEo0DRVM896O5yX8wVCbs/1SA=)
# 2025-03-16 12:08:09.538693 Processando usuário 2500/10000 (+3dY1322IjbX1OhRijMHXQ3d5H1sHjs2uTLhM5WK9yg=)
# 2025-03-16 12:08:34.227061 Processando usuário 3000/10000 (+4oVBzYeFh3lINeycpWrgl6Gxr76lLBOjTh/u9AbkuU=)
# 2025-03-16 12:10:17.185723 Processando usuário 3500/10000 (+5xnVRXzjQvdRUGWTvaqeuBuQl0qnSsIx6brYlVLg7g=)
# 2025-03-16 12:09:28.924524 Processando usuário 4000/10000 (+74LiM18bLdtwTmGxqueOx1SMHLjcaM43QaF1lfJAyw=)
# 2025-03-16 12:09:54.871590 Processando usuário 4500/10000 (+8FvNqsWUdIkGQvN+SqO0oDu3xKZUgRLirNcQHKnaAI=)
# 2025-03-16 12:10:21.231205 Processando usuário 5000/10000 (+9N7/sAjHO9xPT7mqKS1Qt6pi9FtfMp5nY2Bi4enkR4=)
# 2025-03-16 12:10:45.600663 Processando usuário 5500/10000 (+AX+AmfD7BQnroFL3Sz0tIAtU1SiC7Chd0QttM2okAg=)
# 2025-03-16 12:11:14.445195 Processando usuário 6000/10000 (+Bhjda3hLlgrdGsqpuI4Z3+MGul3GJ8iU8m6ynntOrk=)
# 2025-03-16 12:11:42.639615 Processando usuário 6500/10000 (+Cx9kyavv/JmvRHNsr0w6E3U0Aogw3BmrZd/cIoxeRE=)
# 2025-03-16 12:12:10.941984 Processando usuário 7000/10000 (+E7I3UfOxuG8I4kRCnIRB6tZzhvg86aolKgFMJGLbgw=)
# 2025-03-16 12:13:53.242681 Processando usuário 7500/10000 (+FEZdqHdWHvrrjOGWYBLXnUZZp59dVlLJtgZ6nVaTfU=)
# 2025-03-16 12:13:07.761496 Processando usuário 8000/10000 (+GKV8aIyAP6VwTWzaZYDFBvyIXi0EgwCx8RWPVw1kzM=)
# 2025-03-16 12:13:34.080448 Processando usuário 8500/10000 (+HRSW2uOG5ilafB48UU2VUjudBQd1GTBefsWRGelJEo=)
# 2025-03-16 12:14:02.897536 Processando usuário 9000/10000 (+Iddw+7C0UBuHzuQfTR2uxb+pTkME1WVJ3IZ4AIQ+wI=)
# 2025-03-16 12:14:29.273140 Processando usuário 9500/10000 (+JpQy9y94B7c/wWZBE74Hl85WdJBuxMgOnNJngkTXoM=)
# 2025-03-16 12:14:57.405237 Processando usuário 10000/10000 (+L+z9g8gdKZN23WfbSR0hr7bRkOrS27X4lOzi91Z5Rk=)
# Tamanho da Dataframe: 88711
# Removendo linhas sem informações de membros suficientes
# Tamanho da Dataframe pós filtros: 45207
# Truncando tabela
# 2025-03-16 12:15:01.917525 Inserindo 45207 registros na tabela treated_churn_dataset_2025_03_16_12h04m
# 2025-03-16 12:15:02.381399 Inseridos com sucesso
# ##################################################
# 2025-03-16 12:15:02.381514 Processando usuários (10000 / 20000)
# 2025-03-16 12:15:02.381726 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 89335
# Separando DataFrames por usuários
# -> 0 / 10000
# -> 1000 / 10000
# -> 2000 / 10000
# -> 3000 / 10000
# -> 4000 / 10000
# -> 5000 / 10000
# -> 6000 / 10000
# -> 7000 / 10000
# -> 8000 / 10000
# -> 9000 / 10000
# 2025-03-16 12:15:57.945010 Processando usuário 500/10000 (+M9cjKHPMbWsqKuBSKvT8GCPH+wJW9EK/5tqrlcLOF8=)
# 2025-03-16 12:16:25.148956 Processando usuário 1000/10000 (+NMKzrhn36L401Y6l98kRcs4xyZGZ1ef0bCXceydPV4=)
# 2025-03-16 12:16:50.586447 Processando usuário 1500/10000 (+OS5GaotFQpGdnZjuOAHRgEuX4sij0gPjGq9b/aFWww=)
# 2025-03-16 12:17:16.285069 Processando usuário 2000/10000 (+PeTx9phAzX77cdBRR/9/LpkAymVVwGCQScr/SnNWQE=)
# 2025-03-16 12:17:41.133631 Processando usuário 2500/10000 (+QoHevHKZZ/Y42bzHAS4JDD52gqREf8Qcb7OavdEUww=)
# 2025-03-16 12:18:09.348346 Processando usuário 3000/10000 (+Rt7PkwnvX7YTsSfsINCu8rdW0nljngBDKFsjalMqM8=)
# 2025-03-16 12:18:35.235147 Processando usuário 3500/10000 (+T+SwuMddI/NLUPEXAhrn3QnXvtGb7OHeS5zfx9tXZU=)
# 2025-03-16 12:19:05.095621 Processando usuário 4000/10000 (+U9yUuzttl8roCIRYVZSKUc/EkYgMsLMx6J6IwYXdlY=)
# 2025-03-16 12:19:29.342015 Processando usuário 4500/10000 (+VFM/u52QbO7AJjzY4q7jig4lK/09SsK/R8ngRcLVeI=)
# 2025-03-16 12:19:55.887250 Processando usuário 5000/10000 (+WPbuk5QI+ZFV6p9OfhOfofgJIiv+9KLBix7G+05yHA=)
# 2025-03-16 12:20:22.264086 Processando usuário 5500/10000 (+XcPfeCC31OxUIpjTFdvuXDMfYI3IYqvGjwN1W+KAo0=)
# 2025-03-16 12:20:50.496265 Processando usuário 6000/10000 (+YqSUtIK/j9+j61mQWRvL7o+OkQb1OnfgjRDSf1fN54=)
# 2025-03-16 12:21:17.798124 Processando usuário 6500/10000 (+ZzTssSPzvUT7YreRspToA+KGvyKbBmYy1ymb2SX4S0=)
# 2025-03-16 12:21:49.143038 Processando usuário 7000/10000 (+bD15sXAceFCCOOb80EXvFeiBdhrzyrQfL0iGSqI0Lc=)
# 2025-03-16 12:23:33.207066 Processando usuário 7500/10000 (+cKP7X+INilFWLmFTF8AcwIqW3i+YGPRU02IHjEW/Ac=)
# 2025-03-16 12:22:46.740462 Processando usuário 8000/10000 (+dWUeFfxi0kfPjXSc73KsVZ1wPPn9fD3Z9B1zaqgbWk=)
# 2025-03-16 12:23:14.403723 Processando usuário 8500/10000 (+ehOeR32XskN7HG7yhy66WWj9AOHrHjkMapPxtzcerY=)
# 2025-03-16 12:23:43.022319 Processando usuário 9000/10000 (+ftHseGv9UUOEIIcWQ1pZ+WDGFWMTkH6CwL5QZeqQWA=)
# 2025-03-16 12:24:11.044804 Processando usuário 9500/10000 (+gzBvha3PZd4hj5+NTp5u3cwu6PQYKs8SaoMknb0GN4=)
# 2025-03-16 12:24:39.107717 Processando usuário 10000/10000 (+i6oGbelmrRZmLJC6ppXk4bLFRzwES16DF4cBFZqrus=)
# Tamanho da Dataframe: 89335
# Removendo linhas sem informações de membros suficientes
# Tamanho da Dataframe pós filtros: 45746
# 2025-03-16 12:24:43.839022 Inserindo 45746 registros na tabela treated_churn_dataset_2025_03_16_12h04m
# 2025-03-16 12:24:44.379268 Inseridos com sucesso
# ##################################################
# 2025-03-16 12:24:44.380174 Processando usuários (20000 / 30000)
# 2025-03-16 12:24:44.380436 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 87996
# Separando DataFrames por usuários
# -> 0 / 10000
# -> 1000 / 10000
# -> 2000 / 10000
# -> 3000 / 10000
# -> 4000 / 10000
# -> 5000 / 10000
# -> 6000 / 10000
# -> 7000 / 10000
# -> 8000 / 10000
# -> 9000 / 10000
# 2025-03-16 12:25:40.994635 Processando usuário 500/10000 (+jHZ9UiFBHywA5oGtuXQ+OedknNA6ULs0c6LzsCQ+Xg=)
# 2025-03-16 12:26:06.947322 Processando usuário 1000/10000 (+kXj+wfiKByWDhWCFTXWnEYxrZB8H2B8eG0X8nWrZmw=)
# 2025-03-16 12:26:31.407355 Processando usuário 1500/10000 (+lgNzfr6JdvENJ07HB6y1WofwzoNcYeb4l9n68sIzW8=)
# 2025-03-16 12:26:55.363610 Processando usuário 2000/10000 (+mo9sCkkOQCr+m81fQDzU0PG6jJoCbkEYWZLPkWVWNw=)
# 2025-03-16 12:27:20.092391 Processando usuário 2500/10000 (+o+jVF4fDELCCwUguNU/zn2KBzrs0NtooIgkQvjh8lU=)
# 2025-03-16 12:27:48.895148 Processando usuário 3000/10000 (+p7Xr9eEfF8H33qMTRG8OqgH5FpUE44+zrvGB+Cud40=)
# 2025-03-16 12:28:17.089842 Processando usuário 3500/10000 (+qGtQSZbsMeeucjyaZnHrH0Rh3SNN8i0MP0VC5BdZMw=)
# 2025-03-16 12:28:41.227458 Processando usuário 4000/10000 (+rSKXQinYZt/V/FopxUjyxH/9XCnKyWa6LI+KssNBpE=)
# 2025-03-16 12:29:07.946911 Processando usuário 4500/10000 (+sh2IBjGFXy0N76M642QG8KcxIRwGM+/s+Ji057PSj0=)
# 2025-03-16 12:29:35.095022 Processando usuário 5000/10000 (+trJGTooARabXYTMsCWVffTh0ccifteFBVahekw0KJo=)
# 2025-03-16 12:30:03.575811 Processando usuário 5500/10000 (+v+tYyle7GLsrOQrbBIHgDRNG8Inh4frA24vy2Guru8=)
# 2025-03-16 12:30:31.564779 Processando usuário 6000/10000 (+wF0lL2bVYFd6eMdyEy3b5UzZ/IANgRpBmwzF0PFAqY=)
# 2025-03-16 12:30:59.243008 Processando usuário 6500/10000 (+xL78VlxB/G7E6dlap5cC2q3UJccMowYfV7mkvFSvLc=)
# 2025-03-16 12:31:26.028466 Processando usuário 7000/10000 (+yR8Bq8GczsfkfgV7qkY4To3DIi3Gj6KJ5agJy8dxgQ=)
# 2025-03-16 12:31:54.141023 Processando usuário 7500/10000 (+zYN5no9Kth+JpHmdcTefx2f5V+qkAOa0rOOUOkleHI=)
# 2025-03-16 12:32:19.638481 Processando usuário 8000/10000 (/+jnkdZkUYmBDJNdGko+G1LBZVzYAf4V6C0ZSUjSohM=)
# 2025-03-16 12:32:45.622872 Processando usuário 8500/10000 (//trDVmMfvXneqlg0Z8I/nZpM7Hne1R6aA0MJ2fgPgA=)
# 2025-03-16 12:33:12.703709 Processando usuário 9000/10000 (/11U/9PNoN49dm8//nzNRYq8JcKUJ/0+dtx02vOGMt0=)
# 2025-03-16 12:33:41.737871 Processando usuário 9500/10000 (/28EevpDgHvaIL3/pNYEQ02GIrJaiFclefIVFPmjX1E=)
# 2025-03-16 12:34:09.612090 Processando usuário 10000/10000 (/3GfqIGKG+XD69CTkixdidQlrsML4RiKI2eCTZFtpo0=)
# Tamanho da Dataframe: 87996
# Removendo linhas sem informações de membros suficientes
# Tamanho da Dataframe pós filtros: 45224
# 2025-03-16 12:34:14.306851 Inserindo 45224 registros na tabela treated_churn_dataset_2025_03_16_12h04m
# 2025-03-16 12:34:14.883871 Inseridos com sucesso
# ##################################################
# 2025-03-16 12:34:14.884931 Processando usuários (30000 / 40000)
# 2025-03-16 12:34:14.885167 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 90109
# Separando DataFrames por usuários
# -> 0 / 10000
# -> 1000 / 10000
# -> 2000 / 10000
# -> 3000 / 10000
# -> 4000 / 10000
# -> 5000 / 10000
# -> 6000 / 10000
# -> 7000 / 10000
# -> 8000 / 10000
# -> 9000 / 10000
# 2025-03-16 12:35:11.696967 Processando usuário 500/10000 (/4MJt8LfwnyCs6F6PyYqWe25G/YV/JgoFy6aj71K/JY=)
# 2025-03-16 12:35:38.471197 Processando usuário 1000/10000 (/5Vd4hovvqj0OrU1Jig4v12pdYOx1UUHvDXK8StyI+E=)
# 2025-03-16 12:36:04.873826 Processando usuário 1500/10000 (/6eqzwI1H1s/UUURt/gK5rSwVNDePrOWwTZivIQ1TPw=)
# 2025-03-16 12:36:31.705548 Processando usuário 2000/10000 (/7kl/3INmsaHn8TfRqAbH16chVmMWVUHpIBm8bv2hDI=)
# 2025-03-16 12:36:59.053456 Processando usuário 2500/10000 (/8vCXYeMVtSEarVU+af1WhDTCAN0/C122Jar02Fzm20=)
# 2025-03-16 12:37:27.427021 Processando usuário 3000/10000 (/A0QszHPR9oVZrVYSCJ6b4RawbVYO2VnQJ/4iK+dT/s=)
# 2025-03-16 12:37:56.569703 Processando usuário 3500/10000 (/BBa5L4yOdcJxJKiIJ2LA650nJe9BcNLR9qpzT4f4aI=)
# 2025-03-16 12:38:24.985833 Processando usuário 4000/10000 (/CGs6uV0i/t7MWQMB9iTcOQF3kFrND5GY6aAVyLZ3l0=)
# 2025-03-16 12:38:50.467171 Processando usuário 4500/10000 (/DQdebFiWP6dNpx2qOYjcFqtqRroYkqv04dpXmMSZzQ=)
# 2025-03-16 12:39:18.145481 Processando usuário 5000/10000 (/EdrKYsRyzUGYZ1MKF05FY7XzBdqe5TG+mmLQmTv/Ig=)
# 2025-03-16 12:39:44.426350 Processando usuário 5500/10000 (/FnR/mq/OAvfFF3N8qnRYiaLzF9oae6SwULigGW4CGM=)
# 2025-03-16 12:40:11.905545 Processando usuário 6000/10000 (/GswelHB1A/TDi6xh4fzvFlrDxPrjpLC5wqmpNmqJkc=)
# 2025-03-16 12:40:39.565947 Processando usuário 6500/10000 (/I/KMeYXtqOtVNwN9s67P2/UJa5V+dVSgaYbb5+anTw=)
# 2025-03-16 12:41:06.138551 Processando usuário 7000/10000 (/J7Coi6jIUEFPbLMp+uaExpwqUxA/tAfjzGPL6OciGU=)
# 2025-03-16 12:41:34.478342 Processando usuário 7500/10000 (/KGzDIKwCZ6PBwqgPOa2++tKMNnR3aH815NrzENfvcU=)
# 2025-03-16 12:42:00.270866 Processando usuário 8000/10000 (/LQ9YRJar1EmHN2bXzrfJfBJtOE6ghYQMMloDzPJHds=)
# 2025-03-16 12:42:26.883027 Processando usuário 8500/10000 (/MWKP0J7xrhvDTB4W5VjPMTHsHOicgmPfeTH3u3DqDI=)
# 2025-03-16 12:42:54.340507 Processando usuário 9000/10000 (/NbojojO0rgzS26C1Z6VOuVomUKQfLW7Rhg7ib/6HgI=)
# 2025-03-16 12:43:23.430125 Processando usuário 9500/10000 (/OloMk/Mu5+JRmhcEsZ1vqc96vwM9e0Q59WhzMBfPj0=)
# 2025-03-16 12:43:51.367556 Processando usuário 10000/10000 (/Q/7PC4TIwJvcQgSF5+JsJM8d/LF8LNj9Qfgb7WaCjs=)
# Tamanho da Dataframe: 90109
# Removendo linhas sem informações de membros suficientes
# Tamanho da Dataframe pós filtros: 46183
# 2025-03-16 12:43:55.384593 Inserindo 46183 registros na tabela treated_churn_dataset_2025_03_16_12h04m
# 2025-03-16 12:43:55.871839 Inseridos com sucesso
# ##################################################
# 2025-03-16 12:43:55.872694 Processando usuários (40000 / 50000)
# 2025-03-16 12:43:55.872994 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 87741
# Separando DataFrames por usuários
# -> 0 / 10000
# -> 1000 / 10000
# -> 2000 / 10000
# -> 3000 / 10000
# -> 4000 / 10000
# -> 5000 / 10000
# -> 6000 / 10000
# -> 7000 / 10000
# -> 8000 / 10000
# -> 9000 / 10000
# 2025-03-16 12:44:53.478892 Processando usuário 500/10000 (/R4ERO3Cc+QuOAB4aabZgYiNUR7XKXRxRiFyuEIQxvM=)
# 2025-03-16 12:45:20.330325 Processando usuário 1000/10000 (/SDlpkYO+dLWhrGCVGa2DjeYXnbWe381WXW10c7CNLY=)
# 2025-03-16 12:45:45.919996 Processando usuário 1500/10000 (/TKQy1pqTUxYEd9tVeIa7H2lUeCSUPgRsaA0mo8cWTU=)
# 2025-03-16 12:46:10.978915 Processando usuário 2000/10000 (/UTjB8ozMC36+Ed16JYIbu+Zm7BWExGbK36+C/EWECc=)
# 2025-03-16 12:46:36.719296 Processando usuário 2500/10000 (/VgJWzkTvrXsWXYLlbDRdMYgv69+CSLs7qbZsMmQBqc=)
# 2025-03-16 12:47:02.358803 Processando usuário 3000/10000 (/Wlvr7Ex0Sg89jATzsVau2CWmwlvgW49jCaueS73SWU=)
# 2025-03-16 12:47:29.403555 Processando usuário 3500/10000 (/Y06WZZeDrUmonlEHS++P0VVGABOf0cAl+mnfS+e658=)
# 2025-03-16 12:47:57.894381 Processando usuário 4000/10000 (/ZC2FAk5l+jx3npnGLl11S34OsyFJnjEx0C/DbkbAV4=)
# 2025-03-16 12:48:23.372014 Processando usuário 4500/10000 (/aLHMQPzCT1umsWtrO+bIzPZaoAD315eQUB8sMRpb44=)
# 2025-03-16 12:48:49.554693 Processando usuário 5000/10000 (/bXWa0uVLR4jN2odY/zyjmZALh2opLA18X6GLq59zBw=)
# 2025-03-16 12:49:18.143787 Processando usuário 5500/10000 (/ckPLMvOEkge4gFqYyneBYTLY2Ct6cUOIBgBp2YV6Ts=)
# 2025-03-16 12:49:44.385366 Processando usuário 6000/10000 (/dw15WH3gzBGQVg5iwQls91+2jj78W9Tx9FLM+kqixM=)
# 2025-03-16 12:51:25.241833 Processando usuário 6500/10000 (/f3vbzU6jEkg/caGMFjeDCS5zFKF8OMoLqoRSzrrrc8=)
# 2025-03-16 12:50:36.826374 Processando usuário 7000/10000 (/g9wWXurUp6n8JbYlidp9Lf9zn75iiVMvHyybQFJi7s=)
# 2025-03-16 12:51:03.640233 Processando usuário 7500/10000 (/hHNnhVN5N/kcZFJOykGGa+YdHblJJAwjxblmD/Osp0=)
# 2025-03-16 12:51:30.016514 Processando usuário 8000/10000 (/iR1dQvn9q9gPXOlXN7MdF2YDNFnEGXRZmt4GphXJLg=)
# 2025-03-16 12:51:55.004107 Processando usuário 8500/10000 (/jaDxZyto+hUGf1izeycltJj+3xZThSgSJTna5CL8ZU=)
# 2025-03-16 12:52:18.307561 Processando usuário 9000/10000 (/kjqMXzwXsz29XTg7GBF9zjahKfgJss/MsrEodnwlc4=)
# 2025-03-16 12:52:45.386086 Processando usuário 9500/10000 (/lvDeYS9SewoxreAv8y66ofQvqbyWw/8nM37MvJe/dg=)
# 2025-03-16 12:53:11.938010 Processando usuário 10000/10000 (/n1SOiANU7fMxMgIT8ikjDve7dINoT1PD/0bHniTquI=)
# Tamanho da Dataframe: 87741
# Removendo linhas sem informações de membros suficientes
# Tamanho da Dataframe pós filtros: 44952
# 2025-03-16 12:53:16.474379 Inserindo 44952 registros na tabela treated_churn_dataset_2025_03_16_12h04m
# 2025-03-16 12:53:17.181216 Inseridos com sucesso
# ##################################################
# 2025-03-16 12:53:17.182445 Processando usuários (50000 / 60000)
# 2025-03-16 12:53:17.182973 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 88968
# Separando DataFrames por usuários
# -> 0 / 10000
# -> 1000 / 10000
# -> 2000 / 10000
# -> 3000 / 10000
# -> 4000 / 10000
# -> 5000 / 10000
# -> 6000 / 10000
# -> 7000 / 10000
# -> 8000 / 10000
# -> 9000 / 10000
# 2025-03-16 12:54:13.844018 Processando usuário 500/10000 (/oA2JbJKYDZ96Q+n5kc9tu43fedQnvFHWnXRBq42SGs=)
# 2025-03-16 12:54:39.936629 Processando usuário 1000/10000 (/pEa09LUZ/4DqcGmrKr8/EfvR0BNwNxbouFK4J+5Crc=)
# 2025-03-16 12:55:06.927681 Processando usuário 1500/10000 (/qUwt2gy2ktG0CWUoKRNhiGiMBMpUdByQCNsTexGE5E=)
# 2025-03-16 12:55:33.138696 Processando usuário 2000/10000 (/rd+M+8HCWEFIJz6HhLdKLxGmi4E5/2keSrI/xK6pSI=)
# 2025-03-16 12:56:00.150201 Processando usuário 2500/10000 (/sq/vnSLYzeXHQPa2PXsKS+xKE/oxXHiMOR0/EJD/3I=)
# 2025-03-16 12:56:26.990643 Processando usuário 3000/10000 (/u+KDql/Gd9mQGezvKK1dNb+FDXpLTKOoiB30oHvd8Y=)
# 2025-03-16 12:56:52.966340 Processando usuário 3500/10000 (/v9eEBvJI3jYVcJfAeEFb2mxOOIZvmNH0AJTnPO9vpM=)
# 2025-03-16 12:57:20.796956 Processando usuário 4000/10000 (/wHtRIUQJ8/yxQhTKKqM++e6cvAXzlDmUxQUe90QksA=)
# 2025-03-16 12:57:47.750708 Processando usuário 4500/10000 (/xUCdG/8gbaHBi6oWzphaLLwiJcw8k258ykOgk+1dzI=)
# 2025-03-16 12:59:31.215690 Processando usuário 5000/10000 (/yeqV3in2DGHr2Ibmnfye/Hx5JJQv4qFUiymPmC3QZM=)
# 2025-03-16 12:58:44.625673 Processando usuário 5500/10000 (/zsXP/1KF/FgsWWYgXxNnopJwA2rawVMMwCg8sKOWr0=)
# 2025-03-16 12:59:10.079316 Processando usuário 6000/10000 (0/357fcxfjsZQhTBGrA7jMeEo/F3d7BmjJd8r9+LFKo=)
# 2025-03-16 12:59:35.471807 Processando usuário 6500/10000 (00B1NNOJ3S7x7fGV2IBv7g+uS7GTB2GB/EPHh08veLs=)
# 2025-03-16 13:00:01.920735 Processando usuário 7000/10000 (01DDenvKacKFdWlJK0GT+E0Dx1H7XEaBfwDmSVNdbz0=)
# 2025-03-16 13:00:27.020439 Processando usuário 7500/10000 (02M/Kv03wY5/u8qyAYUrh6vtpxHRGDTZuHrLu+PFF+Q=)
# 2025-03-16 13:02:11.401560 Processando usuário 8000/10000 (03U4fp8J9zPT2vLI4PRZqtjTRBdyuZQKluOMa/IB4uQ=)
# 2025-03-16 13:01:22.524352 Processando usuário 8500/10000 (04VNauPJY/ay6d5Ugc02aEXAerIPrpsBStCrje+/lmI=)
# 2025-03-16 13:01:48.595196 Processando usuário 9000/10000 (05kM+7ckyhhJ19i5H0HRAHvbVmeMvjo6F3KkSGafFsY=)
# 2025-03-16 13:02:14.252217 Processando usuário 9500/10000 (06xnVFc/oqiGgZ2xa5S+eMKhFpiHxvq0lnVYDMluxQE=)
# 2025-03-16 13:02:43.607782 Processando usuário 10000/10000 (084JoZ294gWPYHjRiuRce8oADRVPqaN4Kv/f4TedkH0=)
# Tamanho da Dataframe: 88968
# Removendo linhas sem informações de membros suficientes
# Tamanho da Dataframe pós filtros: 45634
# 2025-03-16 13:02:48.468576 Inserindo 45634 registros na tabela treated_churn_dataset_2025_03_16_12h04m
# 2025-03-16 13:02:49.061226 Inseridos com sucesso
# ##################################################
# 2025-03-16 13:02:49.062994 Processando usuários (60000 / 70000)
# 2025-03-16 13:02:49.063261 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 88013
# Separando DataFrames por usuários
# -> 0 / 10000
# -> 1000 / 10000
# -> 2000 / 10000
# -> 3000 / 10000
# -> 4000 / 10000
# -> 5000 / 10000
# -> 6000 / 10000
# -> 7000 / 10000
# -> 8000 / 10000
# -> 9000 / 10000
# 2025-03-16 13:03:44.824855 Processando usuário 500/10000 (09Gqq9phET3FWJtqp7gyEPuH3D2Np8OpePTyxFhqo1M=)
# 2025-03-16 13:04:16.151390 Processando usuário 1000/10000 (0AMjoVncsUcYzkyj2zNgw11v53EZZ1WBol17vImVAsU=)
# 2025-03-16 13:04:44.888188 Processando usuário 1500/10000 (0BPusYaSq+os81Sn8czsFFrfFlCUufM4Uapihh1kIg8=)
# 2025-03-16 13:05:11.998973 Processando usuário 2000/10000 (0Ca5TvIZjBoIoNSTAdtEZ25vs4muOzakmVVd1oHCUpQ=)
# 2025-03-16 13:05:36.171123 Processando usuário 2500/10000 (0DpxcYmHkxil2N7v+pbQoCMrmxDEFxto7/NxNPk4VTY=)
# 2025-03-16 13:06:02.867567 Processando usuário 3000/10000 (0EwiAzrBM46ns3Z2n2FGusqNBj8ZaiETwKp6zbTdzV0=)
# 2025-03-16 13:06:28.944527 Processando usuário 3500/10000 (0G4I2M17lhRLb+lLPLUEQ47OcjOJISsZVK6xWpVhu/w=)
# 2025-03-16 13:06:54.739752 Processando usuário 4000/10000 (0HDvIgn3W4ei1xlaf+VE736uITdQUTHGY5VXbEhbjIE=)
# 2025-03-16 13:07:21.094979 Processando usuário 4500/10000 (0ILzQxdL8HpgcaUbxKuQiYvvE9DEzplKlb7G1zGTVTY=)
# 2025-03-16 13:07:46.624388 Processando usuário 5000/10000 (0JWFI5IcXqZNk0quU9ET5um6+udWAPcLipuBwWKghKs=)
# 2025-03-16 13:08:11.319785 Processando usuário 5500/10000 (0KcrLRJH5UON2I89U6zh3K8adg68B5iIthPU7XECpRE=)
# 2025-03-16 13:08:37.755011 Processando usuário 6000/10000 (0Lq5UifeqKhT4Y/plIfbvdsO+9DMnZe9MmYVQui3vYg=)
# 2025-03-16 13:09:04.580018 Processando usuário 6500/10000 (0N1+/JobycuBTOsWSLEofOS83+LuWJ1qYvGatr9WR4A=)
# 2025-03-16 13:09:30.891313 Processando usuário 7000/10000 (0O9ugvfFiXQRb8h8Hg/qHtMw5UKlK0cXQ8SmVcamnXk=)
# 2025-03-16 13:09:57.158938 Processando usuário 7500/10000 (0PJPSCaJSi6yRvdaEzgONxg59uaGWDS4XgPg5I/5FgQ=)
# 2025-03-16 13:10:23.056504 Processando usuário 8000/10000 (0QOUAQVGmeSn4LrB2uzg66Jxy1urH8j0xptzhf4/WxQ=)
# 2025-03-16 13:10:50.613433 Processando usuário 8500/10000 (0RWWalYwbc5Olye/FJe727EF8FRagqtGOVara8lLZUs=)
# 2025-03-16 13:11:16.897032 Processando usuário 9000/10000 (0Sgf7HW3QDZNHkLLQUDCqY5MoSr2mjPl8v/EVLt4qJ0=)
# 2025-03-16 13:11:41.881187 Processando usuário 9500/10000 (0TlMFOhiA9zaleWi3M5qPseTuh25+9x9nK6Bk3VkeqI=)
# 2025-03-16 13:12:06.397902 Processando usuário 10000/10000 (0Uqv8fSVUyQ2tmjmJMV6Fl144TYZuLhZORRYo9Vrz+g=)
# Tamanho da Dataframe: 88013
# Removendo linhas sem informações de membros suficientes
# Tamanho da Dataframe pós filtros: 45495
# 2025-03-16 13:12:11.378673 Inserindo 45495 registros na tabela treated_churn_dataset_2025_03_16_12h04m
# 2025-03-16 13:12:11.939147 Inseridos com sucesso
# ##################################################
# 2025-03-16 13:12:11.940991 Processando usuários (70000 / 80000)
# 2025-03-16 13:12:11.941224 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 88869
# Separando DataFrames por usuários
# -> 0 / 10000
# -> 1000 / 10000
# -> 2000 / 10000
# -> 3000 / 10000
# -> 4000 / 10000
# -> 5000 / 10000
# -> 6000 / 10000
# -> 7000 / 10000
# -> 8000 / 10000
# -> 9000 / 10000
# 2025-03-16 13:13:06.023031 Processando usuário 500/10000 (0W7TvzuOwPDj3QP8osisnu2/R4AKZ8N60mhArga47VY=)
# 2025-03-16 13:13:32.525357 Processando usuário 1000/10000 (0XFlGwuMccSwcLwpXb+AYSG44xoadvF1z0pXcXz6H9w=)
# 2025-03-16 13:13:57.993912 Processando usuário 1500/10000 (0YS6tG2qOwoZgegMoL1zWi4hCzpg63pdF5nyOV/xVdE=)
# 2025-03-16 13:14:27.142410 Processando usuário 2000/10000 (0ZYt7RghIu2Py/dqzCxVJO8j959u078CX1d2tkBGo2k=)
# 2025-03-16 13:14:53.855858 Processando usuário 2500/10000 (0ak+QjnA2gXC11oSRtWV/FLhVVQspUlcyQaHo707DzM=)
# 2025-03-16 13:15:20.282909 Processando usuário 3000/10000 (0bsQbOUA6zRKjpDMwQqRDcxd+zlo+qUVUzW4qpTjxR0=)
# 2025-03-16 13:15:46.877763 Processando usuário 3500/10000 (0d7hHG3gmKcWSa+DXyoldyyPwJqefs6TCgXFfQmmjhM=)
# 2025-03-16 13:16:12.297982 Processando usuário 4000/10000 (0eKIZyJOUNN1Sjg+3CJf5MZz0hm23D1KyLcUi8GvYVE=)
# 2025-03-16 13:16:38.264425 Processando usuário 4500/10000 (0fRgxihnSAk2cU7lL7E9DJH9543Pp3YybcCOQdfzFlQ=)
# 2025-03-16 13:17:04.933902 Processando usuário 5000/10000 (0gaQmTePt8YTCKMbN5Kjjww2dajauuOaQdqf/J1jx3g=)
# 2025-03-16 13:17:33.088243 Processando usuário 5500/10000 (0hokP9xaQlMpqoXumKrJQgdn4yuANIk1FCZSB1Vjg4E=)
# 2025-03-16 13:17:59.153419 Processando usuário 6000/10000 (0itzxmSUYvmWoyiqgDohQ32x/ViBovbKEo4wDFvVmMA=)
# 2025-03-16 13:18:24.558828 Processando usuário 6500/10000 (0k4VzM0e2elm7PCen10NJBX9+q73zOul43p7LuXBzm8=)
# 2025-03-16 13:18:51.472430 Processando usuário 7000/10000 (0lCijEKbiB1hUogR4Io9GPdCfCQNgQoikDGdE9wOcfM=)
# 2025-03-16 13:19:18.925359 Processando usuário 7500/10000 (0mIyNVQNhyTnK3/maqRTPkGrsCqMRwz8lC+jWfUHjMQ=)
# 2025-03-16 13:19:45.136307 Processando usuário 8000/10000 (0nRdr+EHXs6RWQMCXgmaPwwjSQ6T8qJKKo3Q1mpklX0=)
# 2025-03-16 13:20:10.497882 Processando usuário 8500/10000 (0ogZ5L8FRHOLupdzUDXxend6ubUa16iyMXJifbVQa0Y=)
# 2025-03-16 13:20:37.646276 Processando usuário 9000/10000 (0pqhuuIS0UAvQmF1DBhecNpSsZ8IM3UDmbVaatghSo8=)
# 2025-03-16 13:21:05.869227 Processando usuário 9500/10000 (0r+Z8tV2JjqS71KrkkVfhFQsBIdcm2Zf6TeCe/GPfoE=)
# 2025-03-16 13:21:33.731173 Processando usuário 10000/10000 (0s/5OdGSFT1RHPredFsPVyf+h/Du/lWa7Ncr/cGzETo=)
# Tamanho da Dataframe: 88869
# Removendo linhas sem informações de membros suficientes
# Tamanho da Dataframe pós filtros: 45149
# 2025-03-16 13:21:37.838340 Inserindo 45149 registros na tabela treated_churn_dataset_2025_03_16_12h04m
# 2025-03-16 13:21:38.463249 Inseridos com sucesso
# ##################################################
# 2025-03-16 13:21:38.464125 Processando usuários (80000 / 90000)
# 2025-03-16 13:21:38.464395 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 89503
# Separando DataFrames por usuários
# -> 0 / 10000
# -> 1000 / 10000
# -> 2000 / 10000
# -> 3000 / 10000
# -> 4000 / 10000
# -> 5000 / 10000
# -> 6000 / 10000
# -> 7000 / 10000
# -> 8000 / 10000
# -> 9000 / 10000
# 2025-03-16 13:22:34.427810 Processando usuário 500/10000 (0tAIjEil7bcczLjIgLIzQeqUaP3e/iy1OzVheyiZeXI=)
# 2025-03-16 13:23:03.349787 Processando usuário 1000/10000 (0uNSpFtrZgZhAI69L8YMi25vpi/z+FXdgnIz4dUkWto=)
# 2025-03-16 13:23:31.761410 Processando usuário 1500/10000 (0vWLDEwwlehgc22+K01K5zeVDZHCqENuKVw+vfOv5To=)
# 2025-03-16 13:23:59.996596 Processando usuário 2000/10000 (0wdMoBDYTv3+ri9i3F8AxyJ6vL1sDMI4MKQUrIgcFrU=)
# 2025-03-16 13:24:27.881679 Processando usuário 2500/10000 (0xqi4mBNy6dgaOGqcaJblh7KAyEXX4e+uB8tOab8byo=)
# 2025-03-16 13:24:54.004165 Processando usuário 3000/10000 (0z/++WcycaIHaUTU9btbo0UqxtxHq5/MAjLO73Dkl1E=)
# 2025-03-16 13:25:22.964512 Processando usuário 3500/10000 (1+90u7uVBX3v7hWZUHx0C1bi8IjTZ1PTGsdsqCgU+Sg=)
# 2025-03-16 13:25:51.071381 Processando usuário 4000/10000 (1/GhkS9BzUndmNMywvJ8c/lRXtpymhmfBJBaPYaP5eM=)
# 2025-03-16 13:26:17.181120 Processando usuário 4500/10000 (10O2S0l09oNFFR5Lcbo8FHkPWVIHaxYzATL2sGc/WoQ=)
# 2025-03-16 13:26:45.696208 Processando usuário 5000/10000 (11aVRNfHMkDb+FeGCP/7uMeBFMv4KZsRqAasI59N83Y=)
# 2025-03-16 13:27:14.003849 Processando usuário 5500/10000 (12eqHepRMdin5MFhFmS4Xwslo+XFSi0Hrb/sFa9CNBc=)
# 2025-03-16 13:27:40.162654 Processando usuário 6000/10000 (13sk34CthL5ysxWY+Dpj0errMuN9A0DCWi01z1W1BDg=)
# 2025-03-16 13:28:06.070219 Processando usuário 6500/10000 (15/eGqO8mlNuRhI+//Cn9xbE+7WCK/SpDWCd5efKeBQ=)
# 2025-03-16 13:28:33.652762 Processando usuário 7000/10000 (16DgUefCla6UO+7pM4kU0uRqWEanZYQI5noT89FONlI=)
# 2025-03-16 13:28:59.326106 Processando usuário 7500/10000 (17EE0p09EtDEia4z1ZZy+jKpymuBtDvcdCXKDzHorIM=)
# 2025-03-16 13:29:24.583386 Processando usuário 8000/10000 (18MgbDQJDwqH4b/Te21MgvQXUyu/a1EYQOxaF0+26as=)
# 2025-03-16 13:29:50.889593 Processando usuário 8500/10000 (19XChhl7zMKxh52vyuBMMvT76nxHxLFDO1hNvWAq7pU=)
# 2025-03-16 13:30:13.788143 Processando usuário 9000/10000 (1Ai5+QncZhEUAOrIxx7k+mKCKs6QbChdeM9LM6bARb4=)
# 2025-03-16 13:30:40.669402 Processando usuário 9500/10000 (1Bt0TCVIpxnNnYPLLWSdct9wfgNG6NoSJ8Ae245zwNI=)
# 2025-03-16 13:31:07.535159 Processando usuário 10000/10000 (1D4bzSIXtg5m7MQgLXtEafM75n6/A3QBp4rf6bhCYZs=)
# Tamanho da Dataframe: 89503
# Removendo linhas sem informações de membros suficientes
# Tamanho da Dataframe pós filtros: 45663
# 2025-03-16 13:31:12.693531 Inserindo 45663 registros na tabela treated_churn_dataset_2025_03_16_12h04m
# 2025-03-16 13:31:13.338968 Inseridos com sucesso
# ##################################################
# 2025-03-16 13:31:13.339694 Processando usuários (90000 / 100000)
# 2025-03-16 13:31:13.339939 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 88339
# Separando DataFrames por usuários
# -> 0 / 10000
# -> 1000 / 10000
# -> 2000 / 10000
# -> 3000 / 10000
# -> 4000 / 10000
# -> 5000 / 10000
# -> 6000 / 10000
# -> 7000 / 10000
# -> 8000 / 10000
# -> 9000 / 10000
# 2025-03-16 13:32:09.270885 Processando usuário 500/10000 (1EIx+MI9Mr1KWf+JFUlSM6UHHVWzJCi5B50ftivlWAY=)
# 2025-03-16 13:32:35.468265 Processando usuário 1000/10000 (1FVMky+wPdv90gvo07cuwCpOXQMRPfaxrIu+qLFqo1U=)
# 2025-03-16 13:33:02.020754 Processando usuário 1500/10000 (1GeiUNefTKbpKPCfQ/UUegXwM6xPTHUAgakEIAs61Ro=)
# 2025-03-16 13:33:28.815790 Processando usuário 2000/10000 (1HmeKi+ZUU7YhbWRs2ud0r0CTZazD7TQzulnbDi/DyQ=)
# 2025-03-16 13:33:56.587369 Processando usuário 2500/10000 (1Iw6f+b6Y55TrQPUBtZhvSghjj35VVN8Z5buGlOJiB8=)
# 2025-03-16 13:34:21.608577 Processando usuário 3000/10000 (1K4O9Nt3mwxW1xfRQHlueOLySoxrRGw+rvMrk9oRyLg=)
# 2025-03-16 13:34:48.288301 Processando usuário 3500/10000 (1LMCeOoRBQvwP/u8Ff26WMJ8IJas1XKH6//9tSmpRDE=)
# 2025-03-16 13:35:13.554724 Processando usuário 4000/10000 (1MQUOGzTf4vCYXeOJ8vpH5gArKQvibdhOl6R6oSTLu8=)
# 2025-03-16 13:36:54.106110 Processando usuário 4500/10000 (1NXYmK9qH1zvwodAQosrEpUxLOAcFBuHfcCFcQT5o5g=)
# 2025-03-16 13:36:06.680564 Processando usuário 5000/10000 (1OeGPcOkskJzaLShLC7H5A7Afxu84FYXNjtNYDpENHw=)
# 2025-03-16 13:36:32.910274 Processando usuário 5500/10000 (1PovfVO9dK1VgIqvW4AREWmAkQUYzvqYkGLnxh/dF0o=)
# 2025-03-16 13:38:14.351156 Processando usuário 6000/10000 (1R0ZEJmzlmFLkjfgQ0Bxm2fP2qYLKjfrZnp/saWwGX4=)
# 2025-03-16 13:37:25.549176 Processando usuário 6500/10000 (1SD6VN54b2DgLdeUB4nDBgQKB/f/ZAzmBGhAkvKNkiY=)
# 2025-03-16 13:37:51.803296 Processando usuário 7000/10000 (1TJCkbIIT0WYFtoR6FQi2EkZJXc9GHv90NPbxTfbDUI=)
# 2025-03-16 13:38:18.303830 Processando usuário 7500/10000 (1UTVPtO6B79DiYLhN3yuwSX1uZHPY1oh3BoXIEm9DCw=)
# 2025-03-16 13:38:44.345154 Processando usuário 8000/10000 (1Vl++o709IiUYSBkPmuLPxOBgpI7rKvqQ7zQL9gGdnk=)
# 2025-03-16 13:40:24.452553 Processando usuário 8500/10000 (1WtCQl4weDjCxcNP9EG6Gy9xJ7yjrB6cFf56wd1sdsI=)
# 2025-03-16 13:39:38.510515 Processando usuário 9000/10000 (1Y4KAxU6bboayJ3pvuMTFdG0Ig8vAFr2kqvYCOB7Or4=)
# 2025-03-16 13:40:04.540288 Processando usuário 9500/10000 (1ZGO6XBVQ/9etpSuBGWC0012NAJktjcdNXL2FxtJOi0=)
# 2025-03-16 13:40:32.071674 Processando usuário 10000/10000 (1aTKAIYk+4721m1T/22asmCcASjnCi1d1CEjgkQ8gQw=)
# Tamanho da Dataframe: 88339
# Removendo linhas sem informações de membros suficientes
# Tamanho da Dataframe pós filtros: 45335
# 2025-03-16 13:40:36.605597 Inserindo 45335 registros na tabela treated_churn_dataset_2025_03_16_12h04m
# 2025-03-16 13:40:37.140465 Inseridos com sucesso
# ##################################################
# 2025-03-16 13:40:37.141714 Processando usuários (100000 / 110000)
# 2025-03-16 13:40:37.141981 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 88654
# Separando DataFrames por usuários
# -> 0 / 10000
# -> 1000 / 10000
# -> 2000 / 10000
# -> 3000 / 10000
# -> 4000 / 10000
# -> 5000 / 10000
# -> 6000 / 10000
# -> 7000 / 10000
# -> 8000 / 10000
# -> 9000 / 10000
# 2025-03-16 13:41:32.765743 Processando usuário 500/10000 (1bfoz20xstosMI3LIk0oAc3yTesrmTkz7ZAjwUrPTGc=)
# 2025-03-16 13:41:57.686359 Processando usuário 1000/10000 (1crAhUrhEJICc58TucOMV7ZzoxWO4agfzhtp6D7KtC8=)
# 2025-03-16 13:42:24.318324 Processando usuário 1500/10000 (1e+s5Uv6aTvGPsHE6qeceodfdmWyLhIDACg2jmMDF5s=)
# 2025-03-16 13:42:51.667849 Processando usuário 2000/10000 (1f7I4f+kso1aVe9qKxw+F1ONDRdSdziciTN9TIMjYbo=)
# 2025-03-16 13:43:18.445867 Processando usuário 2500/10000 (1gK2n/eIRnx2dEXiZJ6J7P1+u6fTHfk8teCVgAMKEss=)
# 2025-03-16 13:43:47.571353 Processando usuário 3000/10000 (1hVPlNu1BdvOJGp9aKrNQ6JSPOZcFl66ZgZZThjZuhI=)
# 2025-03-16 13:44:12.553592 Processando usuário 3500/10000 (1iiWiPs9JzzRgse1KPD+cSk4ufnF03xLielsFo08CIo=)
# 2025-03-16 13:44:41.025032 Processando usuário 4000/10000 (1jwgbAye9FhYS0m1oRx6YLqnZHaoAeynrhfesmKRCfw=)
# 2025-03-16 13:45:05.890789 Processando usuário 4500/10000 (1l4sd+GXgpfAdhAhq8oMvHieWYmQnBpxibW7EtSsjtM=)
# 2025-03-16 13:45:31.088471 Processando usuário 5000/10000 (1mG2F9OsVhBeYeLmJQLFdtMOwM0vfPhJJAwSWvUIxqs=)
# 2025-03-16 13:45:53.815102 Processando usuário 5500/10000 (1nSYYiCmP5aaHo+7I+76LGSnB1a8lk8Mp1Cp9xy5pyQ=)
# 2025-03-16 13:46:19.783562 Processando usuário 6000/10000 (1oX3z4vvXGh7mGdrI6m7LtRr6uvgpIyrgfYor+YBvc4=)
# 2025-03-16 13:46:46.623306 Processando usuário 6500/10000 (1pfugF6IR0O/oDT0qB7HFtF4mnxe1/voanDLNzHAkGs=)
# 2025-03-16 13:47:15.707901 Processando usuário 7000/10000 (1qlHo4NOP/0qtKoTR2swnaedCAOTMEUGIwMrOk2WqB4=)
# 2025-03-16 13:47:41.793979 Processando usuário 7500/10000 (1rs8sBUle5CGpd1RcYBivGLvp0lUvtv/wIJ2aLO5z0E=)
# 2025-03-16 13:48:07.958290 Processando usuário 8000/10000 (1t3tmCqs2UPhTc8UOkbU28rHFJByZuB+m/7pD22PXzs=)
# 2025-03-16 13:48:36.090419 Processando usuário 8500/10000 (1uAKkqVvPGtkfTpuS4mJEPkMG0HYdg3GNkwWlAs8dhc=)
# 2025-03-16 13:49:00.503219 Processando usuário 9000/10000 (1vP+tbY7ZqzIIiS0dgirHY3/rG6lqzbg/4r1sJjCzbY=)
# 2025-03-16 13:49:30.133492 Processando usuário 9500/10000 (1wWW1FCGDDBv21uHvNp4o5NGz2Q3EzWNX44jI/iLaUE=)
# 2025-03-16 13:49:56.414556 Processando usuário 10000/10000 (1xfuo522q7CFdgpqo2hysjEgtuOYd3E5DrvNHYe09eI=)
# Tamanho da Dataframe: 88654
# Removendo linhas sem informações de membros suficientes
# Tamanho da Dataframe pós filtros: 45566
# 2025-03-16 13:50:00.383515 Inserindo 45566 registros na tabela treated_churn_dataset_2025_03_16_12h04m
# 2025-03-16 13:50:01.016378 Inseridos com sucesso
# ##################################################
# 2025-03-16 13:50:01.017140 Processando usuários (110000 / 120000)
# 2025-03-16 13:50:01.017432 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 89689
# Separando DataFrames por usuários
# -> 0 / 10000
# -> 1000 / 10000
# -> 2000 / 10000
# -> 3000 / 10000
# -> 4000 / 10000
# -> 5000 / 10000
# -> 6000 / 10000
# -> 7000 / 10000
# -> 8000 / 10000
# -> 9000 / 10000
# 2025-03-16 13:50:59.450943 Processando usuário 500/10000 (1ypnkcT2cYz2dwz8BmshG1M/A5sdvyt/doGupx7QWZg=)
# 2025-03-16 13:51:25.744998 Processando usuário 1000/10000 (1zwZp9YH3Dj4V8TssRuFTiEjzV53GHWUwUHEuNEbzy0=)
# 2025-03-16 13:51:51.764954 Processando usuário 1500/10000 (2/731QoxwSipGF54lTbPz5aJ341Xq/6Aw9LqGAZ002k=)
# 2025-03-16 13:52:18.401189 Processando usuário 2000/10000 (20KXyIHH9CVF1zU2Pd6xEoF9kY7JB4aRu8nUZrhnmJ4=)
# 2025-03-16 13:52:43.637204 Processando usuário 2500/10000 (21S3B+LMx5oKswe7c2iaeFtD/UGktvtplfUorME1pWs=)
# 2025-03-16 13:53:12.456021 Processando usuário 3000/10000 (22ghZ9GJbPTPli6wjyLP1vYetFS5+omu1QOLtqc53UQ=)
# 2025-03-16 13:53:38.476942 Processando usuário 3500/10000 (23nSEhuT/T1TI2hgtXD3jTPB97oRdby9F0lhwKOZXp4=)
# 2025-03-16 13:54:05.821004 Processando usuário 4000/10000 (24qVvECmYAQ9z9G0tqw2xms7YBFhrY54S5XPwFXJMIg=)
# 2025-03-16 13:54:34.247899 Processando usuário 4500/10000 (25xwMcNrjvs3qNn+md2C2VOAwoFQP9cH8EA7XCcL8fk=)
# 2025-03-16 13:55:00.808891 Processando usuário 5000/10000 (2724SDtU1m0bvBvbz7/F+GJOAGsGxWrxGgIJGzgwIZk=)
# 2025-03-16 13:55:30.264873 Processando usuário 5500/10000 (28D0tCUs92zoFCbWp4jMQjbwn/cFG+rOVxDOcvLsvxw=)
# 2025-03-16 13:55:57.149648 Processando usuário 6000/10000 (29O9Pq77Ga3FhCcLS5owR1877yyg7nWStk0f6L5mfvU=)
# 2025-03-16 13:56:25.473060 Processando usuário 6500/10000 (2AaOGcWuYkEPheN0TFZYa9xOytK9zgBGFBFKFoOMJx0=)
# 2025-03-16 13:56:51.853728 Processando usuário 7000/10000 (2BsxuQJpdOpVUjSejf089NbUTDacvLuWOZiMsZWPxKY=)
# 2025-03-16 13:57:19.337960 Processando usuário 7500/10000 (2D2j2m1yC6SZ8WPMGLZrLVbNwh9gw8ws6J0TLHYhjKE=)
# 2025-03-16 13:57:48.234890 Processando usuário 8000/10000 (2EDLij9VJqdXPT7xVguOr92WWFITPu530LeCzQ6NsXE=)
# 2025-03-16 13:58:14.426366 Processando usuário 8500/10000 (2FNdcoNa7oPWSExo6RN+JZ+/h8krgpJ5a2GZ+ujSEMw=)
# 2025-03-16 13:58:43.428023 Processando usuário 9000/10000 (2GcdB0YTncDFyCMl5Z2jnwwZdUig0v5v+1yMsJZYyC4=)
# 2025-03-16 13:59:09.531071 Processando usuário 9500/10000 (2HjFN3Bycg+OpNdAb6xET3cKmsqYmAG/I7olZOOva2Q=)
# 2025-03-16 14:00:51.260291 Processando usuário 10000/10000 (2IwI0EpLVtqqPE0UAXR4x0uK+tp8dW8fzCaYyrMp5ds=)
# Tamanho da Dataframe: 89689
# Removendo linhas sem informações de membros suficientes
# Tamanho da Dataframe pós filtros: 46034
# 2025-03-16 13:59:41.593804 Inserindo 46034 registros na tabela treated_churn_dataset_2025_03_16_12h04m
# 2025-03-16 13:59:42.125659 Inseridos com sucesso
# ##################################################
# 2025-03-16 13:59:42.128558 Processando usuários (120000 / 130000)
# 2025-03-16 13:59:42.128858 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 87611
# Separando DataFrames por usuários
# -> 0 / 10000
# -> 1000 / 10000
# -> 2000 / 10000
# -> 3000 / 10000
# -> 4000 / 10000
# -> 5000 / 10000
# -> 6000 / 10000
# -> 7000 / 10000
# -> 8000 / 10000
# -> 9000 / 10000
# 2025-03-16 14:00:43.604478 Processando usuário 500/10000 (2K6wMOr8CEKLdwMtss/39eUPqAaAzoZO1gmiQ5dxV7A=)
# 2025-03-16 14:01:15.467682 Processando usuário 1000/10000 (2LHO0nSjdOYVG1Pz/3YVwKPkae/BvBzW6GV7tZpVBpI=)
# 2025-03-16 14:01:46.516201 Processando usuário 1500/10000 (2MQRuMh0y5aBvUu1vbY0/jwM77POuqmCtED5nXKIFF4=)
# 2025-03-16 14:02:13.570420 Processando usuário 2000/10000 (2Naw9rdtZ7p6K1z061GCMs0GbkGQWjgbhJGQmVHqWlQ=)
# 2025-03-16 14:02:42.688357 Processando usuário 2500/10000 (2OkFe6PnaXXTpnnZHUrdM4G77B6UC4zHNdGEOdURfSY=)
# 2025-03-16 14:03:13.616464 Processando usuário 3000/10000 (2PwYyd5pVnFwPDERxIqYY5zB2mtz6Mpu1jSTOdjOECg=)
# 2025-03-16 14:03:45.086740 Processando usuário 3500/10000 (2R6Xnc18vPGRSjVfs1W4uZoj4bPf9yj0NsclAS6uj4Q=)
# 2025-03-16 14:04:13.422383 Processando usuário 4000/10000 (2SG+s5tMge57g3ggCfHxemHNVwTXAHDc6cu8YMIKC/Y=)
# 2025-03-16 14:04:45.053699 Processando usuário 4500/10000 (2TS1X7pweCoaov3NS5jEeMv48HpuH03mAI8pinhy2Y8=)
# 2025-03-16 14:05:14.300972 Processando usuário 5000/10000 (2UiKg8f5DQ2tcTwnBJV7m3vpCTeN7FCdlem82Kf/MuQ=)
# 2025-03-16 14:05:41.845163 Processando usuário 5500/10000 (2VuCanJDOZMs/uXt3rriSy8zgg6KHTpYvZwbltfLNk4=)
# 2025-03-16 14:06:11.265982 Processando usuário 6000/10000 (2X/Z34kNUJ0ruH7ndPVXlMfB8zGqX+C54njyb7ifnMU=)
# 2025-03-16 14:06:42.415221 Processando usuário 6500/10000 (2Y8n0p4rjSscy9nTeBozL5NskkzyVu8pPrFgr9UZzJE=)
# 2025-03-16 14:07:13.695176 Processando usuário 7000/10000 (2ZI9TeUE3oeT7FmNCN1x90bdwfKaNK56iOk8mWuLbbg=)
# 2025-03-16 14:07:42.003994 Processando usuário 7500/10000 (2aR0s23w/HkVn9df9+kB5Lg9CPy3QHvNV86mWeKePzs=)
# 2025-03-16 14:08:14.261420 Processando usuário 8000/10000 (2bbSFzdd0ovK7MWX3OYGL/LcSl3+k2Q2iILrqhr2VAs=)
# 2025-03-16 14:08:45.578830 Processando usuário 8500/10000 (2ciyc3a+34kufUuMtfWCQkEBSW81f8eTFM+aprnMbK0=)
# 2025-03-16 14:09:15.166805 Processando usuário 9000/10000 (2dr+/K8FQ9OaI17q7d58NkclYHHuBHK/LjpCNB0rfdU=)
# 2025-03-16 14:09:43.400227 Processando usuário 9500/10000 (2f3kLdoERTx/vIBOfhzaozb5e0MTfdtUaOHE35txIlQ=)
# 2025-03-16 14:10:17.227778 Processando usuário 10000/10000 (2gFw9o44ZpGbLlypydKGCrC8/cPmww9qpMH74ZTsdr4=)
# Tamanho da Dataframe: 87611
# Removendo linhas sem informações de membros suficientes
# Tamanho da Dataframe pós filtros: 45134
# 2025-03-16 14:10:21.847597 Inserindo 45134 registros na tabela treated_churn_dataset_2025_03_16_12h04m
# 2025-03-16 14:11:37.236727 Inseridos com sucesso
# ##################################################
# 2025-03-16 14:11:37.238416 Processando usuários (130000 / 140000)
# 2025-03-16 14:11:37.238689 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 88615
# Separando DataFrames por usuários
# -> 0 / 10000
# -> 1000 / 10000
# -> 2000 / 10000
# -> 3000 / 10000
# -> 4000 / 10000
# -> 5000 / 10000
# -> 6000 / 10000
# -> 7000 / 10000
# -> 8000 / 10000
# -> 9000 / 10000
# 2025-03-16 14:11:23.903300 Processando usuário 500/10000 (2hRAyP2CN6X3WptqWLGGgYRvfXEY52VzJnf3Eo0/SwE=)
# 2025-03-16 14:11:55.619796 Processando usuário 1000/10000 (2idynJYMvhV4zrYk2gY1Pm7m3xxfzbdVBVe2nSZh2VA=)
# 2025-03-16 14:12:28.224678 Processando usuário 1500/10000 (2jmWXnPDjknBDPQ7rrpJB6NGqFm7UypSfgxmxAZXwTY=)
# 2025-03-16 14:12:55.736059 Processando usuário 2000/10000 (2l2lnxgHmL3KaHptfn0LE7hIiRXDsd2JjITen2PopIo=)
# 2025-03-16 14:13:25.137030 Processando usuário 2500/10000 (2mAUDTTbK+NtG5SNI8KF9I7yYZ1RrEmZjuMiJP6rpm4=)
# 2025-03-16 14:13:53.655718 Processando usuário 3000/10000 (2nIRuJQTxB+7XSoyYYBv0ZvT3PU3GIIrkCM2rj7dppM=)
# 2025-03-16 14:14:24.178721 Processando usuário 3500/10000 (2oVhrl1MNOzj/bXrPp9bcCVdNFo6iBIHHCu/6APnFTE=)
# 2025-03-16 14:16:12.656378 Processando usuário 4000/10000 (2pco257YJHTPR6ilVhBHFMIrG51zBJzhYVEQA4O63xo=)
# 2025-03-16 14:15:27.789985 Processando usuário 4500/10000 (2qqWWHpCdFwHV7nKEOseg4CapoOkSXdpst8PCW2jr7E=)
# 2025-03-16 14:15:59.325634 Processando usuário 5000/10000 (2s+5ns+GZG7bMe+QDxn/07ldn4CyEAaTRI4lOdK8hFY=)
# 2025-03-16 14:16:29.708447 Processando usuário 5500/10000 (2t4g1mEsEkftcJsF9fqZd2FWX5l3D8i+gvpbTBjqtTY=)
# 2025-03-16 14:16:58.425178 Processando usuário 6000/10000 (2uCF8a7KUykgPiaCf3BthM8aNc0FuVioOX9zEJxLvrk=)
# 2025-03-16 14:17:31.756033 Processando usuário 6500/10000 (2vJNsqKuAyGwcgvZvYcULFZRzLCfyfNIcelhpolk/Cs=)
# 2025-03-16 14:17:59.763532 Processando usuário 7000/10000 (2wSSyZ0H+Uf3vCeVsoy6am3hBZIVqJ7sa6ieHBs4H3I=)
# 2025-03-16 14:18:31.218008 Processando usuário 7500/10000 (2xYMl4eiPoYNJxcLuLhVroTaqKcvu+ofFINcO6V6ROk=)
# 2025-03-16 14:19:03.235792 Processando usuário 8000/10000 (2yj3n5vAO82dIZ+71x/czgTI/BFZgiOaGpCaG9/nSIw=)
# 2025-03-16 14:19:33.634519 Processando usuário 8500/10000 (2zw5YRp4GgkebcCRJ5O1vbhLfHZoQlMNM3ALOgzvmDk=)
# 2025-03-16 14:20:06.140178 Processando usuário 9000/10000 (3/4bugJtyPpZwMjV9AI1UUcbIuudFhPC8n41oblwucw=)
# 2025-03-16 14:20:36.566039 Processando usuário 9500/10000 (30BahGMsZmpjwSDDUCobixZIy0IOQcT/xRMwexP0cWw=)
# 2025-03-16 14:21:06.955547 Processando usuário 10000/10000 (31N1z5kW+trl0EGqBbdMFPXqzPr3eR0PR5fvm0taRRs=)
# Tamanho da Dataframe: 88615
# Removendo linhas sem informações de membros suficientes
# Tamanho da Dataframe pós filtros: 45322
# 2025-03-16 14:21:11.519718 Inserindo 45322 registros na tabela treated_churn_dataset_2025_03_16_12h04m
# 2025-03-16 14:21:12.211173 Inseridos com sucesso
# ##################################################
# 2025-03-16 14:21:12.212458 Processando usuários (140000 / 150000)
# 2025-03-16 14:21:12.212816 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 88689
# Separando DataFrames por usuários
# -> 0 / 10000
# -> 1000 / 10000
# -> 2000 / 10000
# -> 3000 / 10000
# -> 4000 / 10000
# -> 5000 / 10000
# -> 6000 / 10000
# -> 7000 / 10000
# -> 8000 / 10000
# -> 9000 / 10000
# 2025-03-16 14:22:16.301541 Processando usuário 500/10000 (32YZFcSIUcZawWM52R9umVV6EWH6ikOPbEqaD81NdvQ=)
# 2025-03-16 14:22:46.744205 Processando usuário 1000/10000 (33jO3dOEeee1ZCbArSy7sz81Y9347+lRkbWWLaWyUcI=)
# 2025-03-16 14:23:19.564572 Processando usuário 1500/10000 (34zuHzRv6UjSkKLiAxCMlCb8Y+Zv0NP/KJLjzxFENQM=)
# 2025-03-16 14:23:49.733673 Processando usuário 2000/10000 (366QAMkKvOia0snuFKSbA5qFW2LxfR3Z7Rrej18qKXE=)
# 2025-03-16 14:24:22.482070 Processando usuário 2500/10000 (37GNvrnqtGcQy3ulj9dhX8xUQWsMobcjxHIIYtMw1JA=)
# 2025-03-16 14:24:53.521315 Processando usuário 3000/10000 (38PIFDx+JerT9hIJa+X3pvYdomxsY/FsqfvgU04gmeQ=)
# 2025-03-16 14:25:25.364428 Processando usuário 3500/10000 (39e6GguFNBYGptKnKiejCMF0LvgNmSJIRTT8QKxEkj4=)
# 2025-03-16 14:25:56.913154 Processando usuário 4000/10000 (3ArIEe2bTMWce/mCzhcZOi+sJgm8k6VJYOI+2NpgWvE=)
# 2025-03-16 14:26:27.158120 Processando usuário 4500/10000 (3C2bYAFe8UjnX14AHH7bbrS5LzUAZGfH2tA5Q9kW+h0=)
# 2025-03-16 14:26:55.651102 Processando usuário 5000/10000 (3DDt+HlBCRPGKr7BZtIkZiDYjNBbqMxRdfa4NP/36po=)
# 2025-03-16 14:27:24.892501 Processando usuário 5500/10000 (3EPzNVJWTkBhUCL7hL9i240T3UmqmduuPuW9VbtIDkk=)
# 2025-03-16 14:27:57.246208 Processando usuário 6000/10000 (3FaV9WZKQHPjBYAsnvjNsWkIxj2cib3JC/8ZKmW/cck=)
# 2025-03-16 14:28:30.571765 Processando usuário 6500/10000 (3Gn7JKREhLLuhkl2fjZNN13Dcv1H7qz9COhJLESBXso=)
# 2025-03-16 14:29:01.324337 Processando usuário 7000/10000 (3Hz09J6JYs32/CSip/17D3KGGw378BtWav60nTOGCMg=)
# 2025-03-16 14:29:33.921922 Processando usuário 7500/10000 (3JDAHHbTkdQht3dMKRlr4hOZ0GB8WCLe6D2PdwyL8lo=)
# 2025-03-16 14:30:03.336580 Processando usuário 8000/10000 (3KP4Gy8g9ScT4oD8MIXQP6q7b97JqhHP8v38HVpnMEI=)
# 2025-03-16 14:30:33.535789 Processando usuário 8500/10000 (3LVtBpV3RO0kzJ0Tc9AAt+WBEXjxs1XK2bH3WTFyT5M=)
# 2025-03-16 14:31:02.710660 Processando usuário 9000/10000 (3MlV4VIXrce20Z6+5OZBeqy+udvWW8tm1KUtsHcxTlM=)
# 2025-03-16 14:31:32.795205 Processando usuário 9500/10000 (3Ns5T1197oQzD8RR9hZAV0AUYysQi9Go0sCv6daBG0c=)
# 2025-03-16 14:32:00.415943 Processando usuário 10000/10000 (3OxYlKSLMeInJx58Av5oQV31zupnlEhYUhttmORxMV4=)
# Tamanho da Dataframe: 88689
# Removendo linhas sem informações de membros suficientes
# Tamanho da Dataframe pós filtros: 45299
# 2025-03-16 14:32:05.308894 Inserindo 45299 registros na tabela treated_churn_dataset_2025_03_16_12h04m
# 2025-03-16 14:32:05.892159 Inseridos com sucesso
# ##################################################
# 2025-03-16 14:32:05.893380 Processando usuários (150000 / 160000)
# 2025-03-16 14:32:05.893740 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 88958
# Separando DataFrames por usuários
# -> 0 / 10000
# -> 1000 / 10000
# -> 2000 / 10000
# -> 3000 / 10000
# -> 4000 / 10000
# -> 5000 / 10000
# -> 6000 / 10000
# -> 7000 / 10000
# -> 8000 / 10000
# -> 9000 / 10000
# 2025-03-16 14:33:10.278923 Processando usuário 500/10000 (3Q7Y9vh9104D5jz3StV4+bTQtCkixgbsaSwxQ/Fm2Y4=)
# 2025-03-16 14:33:38.430070 Processando usuário 1000/10000 (3RMbP9b/H9cOvfHzLG2xeG50dAQmj+39J2SEgrXjxYw=)
# 2025-03-16 14:34:10.515851 Processando usuário 1500/10000 (3SZjW7A2AST6ctboFjrqIqcdRHr2z8nngbT/CmVRDu0=)
# 2025-03-16 14:35:54.462486 Processando usuário 2000/10000 (3TgUcwoXsAGEnoifirbQzJCexXOsAxLVdO0kZvSRE6w=)
# 2025-03-16 14:35:11.551701 Processando usuário 2500/10000 (3UkC/q13towdazuX5VL7yRCXrcxp1Sp5nOWt7OVoXNM=)
# 2025-03-16 14:35:42.923873 Processando usuário 3000/10000 (3VtVov0htFk7tdoo/uW2ZFuZ2VpPj80j0R5YKYP4Brk=)
# 2025-03-16 14:36:16.834498 Processando usuário 3500/10000 (3X/eYRrTFHmBDyO/s/CQT4q8Mjf9Mo6cGtFxnJeJU1A=)
# 2025-03-16 14:36:45.609403 Processando usuário 4000/10000 (3Y8YRLVJkSvbjsSkS1QbMVdVnDtWceH0cl3gNWwbBuc=)
# 2025-03-16 14:37:15.527209 Processando usuário 4500/10000 (3ZF0IXy+GWmX2UGAYRI6n8i0iApRxLQ80jNLCybWfMs=)
# 2025-03-16 14:38:59.913388 Processando usuário 5000/10000 (3aVZuCXIW5bwg3Dcvjoc2ygFFXAKQD7MA5SaKBLj5CA=)
# 2025-03-16 14:38:14.057830 Processando usuário 5500/10000 (3bdu4YTNzGhJMx/4gJ+DP4zgnH4TogJaMyNaqz+ujSQ=)
# 2025-03-16 14:38:45.514668 Processando usuário 6000/10000 (3cob83bTOcZhkxHr5Xt7k89lvBtI/p1nmu9KRCAFKt8=)
# 2025-03-16 14:39:16.858240 Processando usuário 6500/10000 (3dyokZKyjrt+pG3LN5Ee3uxi8xlR1Hz/sBenzlb/w8w=)
# 2025-03-16 14:39:53.757031 Processando usuário 7000/10000 (3f7l5WQsNJXG2VNsixdCfODpctqWiYcTrtW6/FqoDmU=)
# 2025-03-16 14:40:26.429398 Processando usuário 7500/10000 (3gIDYu/FLuCJN6ntUn6koN2ejv1glC5Zano0q19M4xY=)
# 2025-03-16 14:41:02.219682 Processando usuário 8000/10000 (3hOagOP69AFjew4sNPsQALMVEWt59iNY9cB+oI3AZKI=)
# 2025-03-16 14:41:33.997095 Processando usuário 8500/10000 (3iaz8oPUmZp9VVe6NdQs4Ni40nrBnbfpQkOt0hT4Cpw=)
# 2025-03-16 14:42:06.551943 Processando usuário 9000/10000 (3jld6Zu7K4tQKBX5S+aMY6F1eZ/BfFAyxOaY8kv/e+Q=)
# 2025-03-16 14:42:40.201659 Processando usuário 9500/10000 (3kzREf+GGSvJ+eB50oTUcQsW+psIIwJfRfY8tM//TCo=)
# 2025-03-16 14:43:13.381109 Processando usuário 10000/10000 (3m5nR3hEIAKwpqOG6hXKwh+1Xw0ppc7UOSMG0o8sX2A=)
# Tamanho da Dataframe: 88958
# Removendo linhas sem informações de membros suficientes
# Tamanho da Dataframe pós filtros: 45774
# 2025-03-16 14:43:18.409243 Inserindo 45774 registros na tabela treated_churn_dataset_2025_03_16_12h04m
# 2025-03-16 14:43:19.056428 Inseridos com sucesso
# ##################################################
# 2025-03-16 14:43:19.057906 Processando usuários (160000 / 170000)
# 2025-03-16 14:43:19.058169 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 87798
# Separando DataFrames por usuários
# -> 0 / 10000
# -> 1000 / 10000
# -> 2000 / 10000
# -> 3000 / 10000
# -> 4000 / 10000
# -> 5000 / 10000
# -> 6000 / 10000
# -> 7000 / 10000
# -> 8000 / 10000
# -> 9000 / 10000
# 2025-03-16 14:44:20.948294 Processando usuário 500/10000 (3nGLIKGXtR9Dbm14bd+sMJoNOGO6h7budwZl0xNuZlY=)
# 2025-03-16 14:44:51.281128 Processando usuário 1000/10000 (3oWLy1Td0whZnX0wBMoTVxhz0jRW3rDHKzyRtW72fX0=)
# 2025-03-16 14:46:40.615178 Processando usuário 1500/10000 (3paU5wSSx3TKnCU8A2yWVon4oWuhmWk+cMnV1SmuXck=)
# 2025-03-16 14:45:55.301030 Processando usuário 2000/10000 (3qf0FOpdbnewkzvk73T2AzCbzCSvPSwKD96YSA2yWqE=)
# 2025-03-16 14:46:31.574960 Processando usuário 2500/10000 (3rmDxK3lvsRCmVTkZCpxiy382E2oUoVwNgapAcssN2c=)
# 2025-03-16 14:47:04.685994 Processando usuário 3000/10000 (3swq4dWFBuOSUhE/bWI9dL8hCWj2pCCGTFgMvc8NsLI=)
# 2025-03-16 14:47:39.836860 Processando usuário 3500/10000 (3u5DJKGzA2QSdifNuqBwE8vCkyXGTVf3pEPQpyxVy3Q=)
# 2025-03-16 14:48:15.874064 Processando usuário 4000/10000 (3vHTFMtJCRXJfLA2pjYf9E6aoAeL3pnnirxluOMyi+k=)
# 2025-03-16 14:50:05.991147 Processando usuário 4500/10000 (3wRItUEerloAn8bR4IePJ4r/Izco5tZeY/iiB0aAxsc=)
# 2025-03-16 14:49:27.748922 Processando usuário 5000/10000 (3xf+Ocrv3/sTPmqFulu3FJcS18skEV0X2eM4kL1Ju7k=)
# 2025-03-16 14:50:01.649053 Processando usuário 5500/10000 (3ymMznt+GDu5GLZNbWFZjhzdomDe56bnbl2nBCqGbUc=)
# 2025-03-16 14:50:36.016831 Processando usuário 6000/10000 (3zsf3X4t+xOoeK1QhzXXSEOAcWKylb1e3hg36lhmP2k=)
# 2025-03-16 14:51:09.191521 Processando usuário 6500/10000 (4/5zak4jLARUYC6sZnrFoGDevPcXBMIMzyImWJy8mEM=)
# 2025-03-16 14:51:43.813777 Processando usuário 7000/10000 (40JAzyYIFoQCz8BkAwLymlPp4tKksuoo1rZ9+qjHxiY=)
# 2025-03-16 14:52:17.847786 Processando usuário 7500/10000 (41Qz4LqdTbgk/vB62X0WzLNAm6ljJYP4QXzMMEz/Z58=)
# 2025-03-16 14:52:49.573858 Processando usuário 8000/10000 (42hRIBJ5JbOx02Ohpy/ZHBeKtg2Srwj7Gvts6U3Zau8=)
# 2025-03-16 14:53:23.226446 Processando usuário 8500/10000 (43wvG5tpeH/29gA6bveZPJWAjjDdL6ZJa0jqbZKA5Uw=)
# 2025-03-16 14:53:56.412168 Processando usuário 9000/10000 (454zxxaWjXo/mq2CDl6itX+PpQFUC18MPg1zyg5R/EM=)
# 2025-03-16 14:54:28.797482 Processando usuário 9500/10000 (46DvBCNeQ5RSCa6yTGnz5e5D/rxr161cjIEhuVTRk6w=)
# 2025-03-16 14:55:00.553818 Processando usuário 10000/10000 (47HlvAoIXUn3EfEAOiHkNJ2j5UoV0uL4iAoGmiDKz0g=)
# Tamanho da Dataframe: 87798
# Removendo linhas sem informações de membros suficientes
# Tamanho da Dataframe pós filtros: 44635
# 2025-03-16 14:55:05.664928 Inserindo 44635 registros na tabela treated_churn_dataset_2025_03_16_12h04m
# 2025-03-16 14:55:06.396156 Inseridos com sucesso
# ##################################################
# 2025-03-16 14:55:06.397331 Processando usuários (170000 / 180000)
# 2025-03-16 14:55:06.397591 Separando um DF apenas com os usuários em questão
# ...
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:04.894887 Processando usuários (3860000 / 3870000)
# 2025-03-16 20:21:04.894899 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:04.919648 Processando usuários (3870000 / 3880000)
# 2025-03-16 20:21:04.919660 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:04.942867 Processando usuários (3880000 / 3890000)
# 2025-03-16 20:21:04.942879 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:04.966408 Processando usuários (3890000 / 3900000)
# 2025-03-16 20:21:04.966421 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:04.990160 Processando usuários (3900000 / 3910000)
# 2025-03-16 20:21:04.990175 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.013695 Processando usuários (3910000 / 3920000)
# 2025-03-16 20:21:05.013708 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.037740 Processando usuários (3920000 / 3930000)
# 2025-03-16 20:21:05.037753 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.063461 Processando usuários (3930000 / 3940000)
# 2025-03-16 20:21:05.063476 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.087484 Processando usuários (3940000 / 3950000)
# 2025-03-16 20:21:05.087496 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.110765 Processando usuários (3950000 / 3960000)
# 2025-03-16 20:21:05.110777 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.132065 Processando usuários (3960000 / 3970000)
# 2025-03-16 20:21:05.132076 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.154710 Processando usuários (3970000 / 3980000)
# 2025-03-16 20:21:05.154722 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.179843 Processando usuários (3980000 / 3990000)
# 2025-03-16 20:21:05.179855 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.204696 Processando usuários (3990000 / 4000000)
# 2025-03-16 20:21:05.204708 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.229522 Processando usuários (4000000 / 4010000)
# 2025-03-16 20:21:05.229535 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.254543 Processando usuários (4010000 / 4020000)
# 2025-03-16 20:21:05.254557 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.279941 Processando usuários (4020000 / 4030000)
# 2025-03-16 20:21:05.279953 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.305370 Processando usuários (4030000 / 4040000)
# 2025-03-16 20:21:05.305381 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.332048 Processando usuários (4040000 / 4050000)
# 2025-03-16 20:21:05.332060 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.355954 Processando usuários (4050000 / 4060000)
# 2025-03-16 20:21:05.355966 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.381691 Processando usuários (4060000 / 4070000)
# 2025-03-16 20:21:05.381703 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.405946 Processando usuários (4070000 / 4080000)
# 2025-03-16 20:21:05.405958 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.430654 Processando usuários (4080000 / 4090000)
# 2025-03-16 20:21:05.430665 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.456195 Processando usuários (4090000 / 4100000)
# 2025-03-16 20:21:05.456208 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.480212 Processando usuários (4100000 / 4110000)
# 2025-03-16 20:21:05.480225 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.503064 Processando usuários (4110000 / 4120000)
# 2025-03-16 20:21:05.503076 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.526710 Processando usuários (4120000 / 4130000)
# 2025-03-16 20:21:05.526723 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.551052 Processando usuários (4130000 / 4140000)
# 2025-03-16 20:21:05.551063 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.575993 Processando usuários (4140000 / 4150000)
# 2025-03-16 20:21:05.576005 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.600902 Processando usuários (4150000 / 4160000)
# 2025-03-16 20:21:05.600914 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.625734 Processando usuários (4160000 / 4170000)
# 2025-03-16 20:21:05.625746 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.649659 Processando usuários (4170000 / 4180000)
# 2025-03-16 20:21:05.649671 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.673899 Processando usuários (4180000 / 4190000)
# 2025-03-16 20:21:05.673912 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.697863 Processando usuários (4190000 / 4200000)
# 2025-03-16 20:21:05.697876 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.722305 Processando usuários (4200000 / 4210000)
# 2025-03-16 20:21:05.722319 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.746629 Processando usuários (4210000 / 4220000)
# 2025-03-16 20:21:05.746642 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.772154 Processando usuários (4220000 / 4230000)
# 2025-03-16 20:21:05.772166 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.797813 Processando usuários (4230000 / 4240000)
# 2025-03-16 20:21:05.797836 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.822897 Processando usuários (4240000 / 4250000)
# 2025-03-16 20:21:05.822910 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.847662 Processando usuários (4250000 / 4260000)
# 2025-03-16 20:21:05.847674 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.871895 Processando usuários (4260000 / 4270000)
# 2025-03-16 20:21:05.871907 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.894482 Processando usuários (4270000 / 4280000)
# 2025-03-16 20:21:05.894494 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.919108 Processando usuários (4280000 / 4290000)
# 2025-03-16 20:21:05.919120 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.943383 Processando usuários (4290000 / 4300000)
# 2025-03-16 20:21:05.943395 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.967874 Processando usuários (4300000 / 4310000)
# 2025-03-16 20:21:05.967891 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:05.990732 Processando usuários (4310000 / 4320000)
# 2025-03-16 20:21:05.990743 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:06.015886 Processando usuários (4320000 / 4330000)
# 2025-03-16 20:21:06.015898 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:06.041758 Processando usuários (4330000 / 4340000)
# 2025-03-16 20:21:06.041772 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:06.069395 Processando usuários (4340000 / 4350000)
# 2025-03-16 20:21:06.069407 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:06.094083 Processando usuários (4350000 / 4360000)
# 2025-03-16 20:21:06.094095 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:06.118676 Processando usuários (4360000 / 4370000)
# 2025-03-16 20:21:06.118688 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:06.141127 Processando usuários (4370000 / 4380000)
# 2025-03-16 20:21:06.141139 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:06.165298 Processando usuários (4380000 / 4390000)
# 2025-03-16 20:21:06.165310 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:06.190052 Processando usuários (4390000 / 4400000)
# 2025-03-16 20:21:06.190064 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:06.213566 Processando usuários (4400000 / 4410000)
# 2025-03-16 20:21:06.213584 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:06.238996 Processando usuários (4410000 / 4420000)
# 2025-03-16 20:21:06.239009 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:06.263100 Processando usuários (4420000 / 4430000)
# 2025-03-16 20:21:06.263112 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:06.288362 Processando usuários (4430000 / 4440000)
# 2025-03-16 20:21:06.288373 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:06.315495 Processando usuários (4440000 / 4450000)
# 2025-03-16 20:21:06.315507 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:06.340315 Processando usuários (4450000 / 4460000)
# 2025-03-16 20:21:06.340328 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:06.364275 Processando usuários (4460000 / 4470000)
# 2025-03-16 20:21:06.364287 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:06.386914 Processando usuários (4470000 / 4480000)
# 2025-03-16 20:21:06.386926 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:06.411927 Processando usuários (4480000 / 4490000)
# 2025-03-16 20:21:06.411940 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0
# 2025-03-16 20:21:06.437991 Processando usuários (4490000 / 4500000)
# 2025-03-16 20:21:06.438003 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 0
# Separando DataFrames por usuários
# Tamanho da Dataframe: 0

# %%
DUCK_DB_CONN.close()

# %%
treated_df[['safra', 'is_churn', 'is_cancel', 'no_churn_information', 'num_unq', 'num_unq-1M', 'num_unq-2M', 'total_secs', 'total_secs-1M', 'total_secs-2M', 'num_25', 'num_25-1M', 'num_25-2M', 'num_50', 'num_50-1M', 'num_50-2M', 'num_75', 'num_75-1M', 'num_75-2M', 'num_985', 'num_985-1M', 'num_985-2M', 'num_100', 'num_100-1M', 'num_100-2M']]
# Out:
#           safra  is_churn  is_cancel  no_churn_information  num_unq  \
# 4441153  201612     False      False                  True      184
# 4441160  201606      True      False                 False      586
# 4441161  201608      True      False                 False     1439
# 4441163  201608     False      False                 False      203
# 4441164  201609     False      False                 False      288
# ...         ...       ...        ...                   ...      ...
# 4505071  201608     False      False                 False      289
# 4505072  201609     False      False                 False      333
# 4505073  201610      True      False                 False      282
# 4505074  201611     False      False                 False      481
# 4505075  201612     False      False                  True      170
#
#          num_unq-1M  num_unq-2M  total_secs  total_secs-1M  total_secs-2M  \
# 4441153         NaN         NaN       31786            NaN            NaN
# 4441160         NaN         NaN      154839            NaN            NaN
# 4441161         NaN         NaN      246362            NaN            NaN
# 4441163         NaN         NaN       54199            NaN            NaN
# 4441164         NaN         NaN       88995            NaN            NaN
# ...             ...         ...         ...            ...            ...
# 4505071        82.0       216.0       80181        16079.0        78065.0
# 4505072       289.0        82.0       69545        80181.0        16079.0
# 4505073       333.0       289.0       49442        69545.0        80181.0
# 4505074       282.0       333.0      102839        49442.0        69545.0
# 4505075       481.0       282.0       54663       102839.0        49442.0
#
#          ...  num_50-2M  num_75  num_75-1M  num_75-2M  num_985  num_985-1M  \
# 4441153  ...        NaN       4        NaN        NaN       23         NaN
# 4441160  ...        NaN      48        NaN        NaN       31         NaN
# 4441161  ...        NaN      91        NaN        NaN      107         NaN
# 4441163  ...        NaN      11        NaN        NaN        8         NaN
# 4441164  ...        NaN      13        NaN        NaN       22         NaN
# ...      ...        ...     ...        ...        ...      ...         ...
# 4505071  ...       16.0      31        6.0       13.0       34         3.0
# 4505072  ...       16.0      42       31.0        6.0       43        34.0
# 4505073  ...       47.0      12       42.0       31.0       15        43.0
# 4505074  ...       42.0      55       12.0       42.0       43        15.0
# 4505075  ...       18.0       9       55.0       12.0        9        43.0
#
#          num_985-2M  num_100  num_100-1M  num_100-2M
# 4441153         NaN       96         NaN         NaN
# 4441160         NaN      524         NaN         NaN
# 4441161         NaN      809         NaN         NaN
# 4441163         NaN      186         NaN         NaN
# 4441164         NaN      306         NaN         NaN
# ...             ...      ...         ...         ...
# 4505071        17.0      288        52.0       308.0
# 4505072         3.0      234       288.0        52.0
# 4505073        34.0      206       234.0       288.0
# 4505074        43.0      410       206.0       234.0
# 4505075        15.0      244       410.0       206.0
#
# [32836 rows x 25 columns]

# %%
treated_df['no_churn_information'].value_counts()

# %%
treated_df[treated_df['no_churn_information'] == True]

# %%
treated_df[treated_df['msno'] == '+++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw='][['safra', 'is_churn', 'is_cancel', 'no_churn_information']]

# %%
treated_df.columns

# %%
input('TODO: DELETAR LINHAS COM is_churn = NaN e sem informações de membros')

# %%
# upload_dataframe_to_duck_db(treated_df)
