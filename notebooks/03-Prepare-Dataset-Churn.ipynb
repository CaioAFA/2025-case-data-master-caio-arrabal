# %%
# %load_ext autoreload
# %autoreload 2

# %%
from Utils.DataLoader import DataLoader
from Utils.DuckDb.DuckDb import DuckDb
from Utils.DatasetProcessor.DatasetProcessorUtils import DatasetProcessorUtils
from Utils.DatasetProcessor.PrepareDatasetProcessor import PrepareDatasetProcessor
from Utils.Safra import SafraUtils
from datetime import datetime
import pandas as pd
from typing import List
import math
import numpy as np

# %%
MININUM_USERS_TO_CONSIDER = 1_500_000
BATCH_SIZE_TO_GET_DATA_FROM_DATABASE = 50_000
PROCESS_USERS_BATCH_SIZE = 10_000

# MININUM_USERS_TO_CONSIDER = 10_000
# BATCH_SIZE_TO_GET_DATA_FROM_DATABASE = 10_000
# PROCESS_USERS_BATCH_SIZE = 10_000

# %%
# Max safra = 201702, so we need to consider three months before
MAX_SAFRA_TO_CONSIDER = 201611

# %%
datetime_string_identifier = datetime.now().strftime('%Y_%m_%d_%Hh%Mm')
DATABASE_NEW_TABLE = 'treated_churn_dataset_' + datetime_string_identifier
TEMP_TABLE_NAME = 'temp_' + datetime_string_identifier

# %%
PREPARE_DATASET_UTILS = DatasetProcessorUtils()
DUCK_DB_UTILS = DuckDb()
SAFRA_UTILS = SafraUtils()
PREPARE_DATASET_PROCESSOR = PrepareDatasetProcessor(
    duck_db=DUCK_DB_UTILS,
    duck_db_table_name=DATABASE_NEW_TABLE,
    process_users_batch_size=PROCESS_USERS_BATCH_SIZE,
    max_safra_to_consider=MAX_SAFRA_TO_CONSIDER
)

# %%
full_dataframe = PREPARE_DATASET_UTILS.get_complete_dataset(
    batch_size=BATCH_SIZE_TO_GET_DATA_FROM_DATABASE,
    min_users_to_consider=MININUM_USERS_TO_CONSIDER
)
# full_dataframe = pd.read_csv('../data/full-dataframe-cached-complete.csv')
# Out:
# Processando count: 0
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Processando count: 50000
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Processando count: 100000
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Processando count: 150000
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Processando count: 200000
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ...

# %%
full_dataframe.to_csv(f'../data/full-dataframe-cached-{datetime_string_identifier}.csv', index=False)

# %%
users_msno = list(full_dataframe['msno'].unique())

# %%
last_batch_df = PREPARE_DATASET_PROCESSOR.process_dataframe(
    full_dataframe,
    users_msno
)
# Out:
# Total de iterações: 450
# Tamanho do Dataframe completo: 4505078
# 2025-03-21 21:24:34.199015 Processando usuários (0 / 10000)
# 2025-03-21 21:24:34.199233 Separando um DF apenas com os usuários em questão
# Tamanho do Dataframe dos usuários do batch: 88711
# Separando DataFrames por usuários
# -> 0 / 10000
# -> 1000 / 10000
# -> 2000 / 10000
# -> 3000 / 10000
# -> 4000 / 10000
# -> 5000 / 10000
# -> 6000 / 10000
# -> 7000 / 10000
# -> 8000 / 10000
# -> 9000 / 10000
# Finalizado
# 2025-03-21 21:25:08.864486 Processando usuário 0/10000 (+++FOrTS7ab3tIgIh8eWwX4FqRv8w/FoiOuyXsFvphY=)
# 2025-03-21 21:25:57.672990 Processando usuário 500/10000 (+/E5Yqp54iXtB0OFKuzof28ZIr3pYYu0SGX+Kwr/Oz0=)
# 2025-03-21 21:26:48.845319 Processando usuário 1000/10000 (+0MeUJe1cGb4O97gJoTPUPjiONQzi9BmxDuKRZn+E2o=)
# 2025-03-21 21:27:37.270586 Processando usuário 1500/10000 (+1VIk9gpQ9cOLXPbQOxeLm2VjH9oKWtHyIMwe+BfFt0=)
# ...

# %%
DUCK_DB_UTILS.commit()

# %%
len(last_batch_df)
# Out:
# 59842

# %%
DATABASE_NEW_TABLE
# Out:
# 'treated_churn_dataset_2025_03_21_19h36m'

# %%
last_batch_df[['safra', 'is_churn', 'is_cancel', 'no_churn_information', 'num_unq', 'num_unq-1M', 'num_unq-2M', 'total_secs', 'total_secs-1M', 'total_secs-2M', 'num_25', 'num_25-1M', 'num_25-2M', 'num_50', 'num_50-1M', 'num_50-2M', 'num_75', 'num_75-1M', 'num_75-2M', 'num_985', 'num_985-1M', 'num_985-2M', 'num_100', 'num_100-1M', 'num_100-2M']]
# Out:
#          safra  is_churn  is_cancel  no_churn_information  num_unq  \
# 87160   201612     False      False                  True      184
# 87161   201701     False      False                  True      201
# 87162   201702     False      False                  True       93
# 87163   201501      True      False                 False     1163
# 87164   201502      True      False                 False     1123
# ...        ...       ...        ...                   ...      ...
# 151080  201610      True      False                 False      282
# 151081  201611     False      False                 False      481
# 151082  201612     False      False                  True      170
# 151083  201701     False       True                  True      384
# 151084  201702     False      False                  True      279
#
#         num_unq-1M  num_unq-2M  total_secs  total_secs-1M  total_secs-2M  ...  \
# 87160          NaN         NaN       31786            NaN            NaN  ...
# ...
